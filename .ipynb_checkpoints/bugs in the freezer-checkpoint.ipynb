# %%
import pandas as pd
import warnings
import numpy as np
import itertools

import statsmodels.api as sm
from statsmodels.tsa.stattools import acf  
from statsmodels.tsa.stattools import pacf
from statsmodels.tsa.seasonal import seasonal_decompose

import matplotlib
# %matplotlib inline

import matplotlib.pyplot as plt
#plt.style.use('fivethirtyeight')

from sklearn import linear_model

import tensorflow as tf
sess = tf.Session()

# %%
# Read Power Data
power_path = "../../../data/testing/power.csv" # "power.csv"
power = pd.read_csv(power_path, index_col=[0], parse_dates=True, names=["dt", "power"])

# %%
# Read Ambient Temperature Data
temp_path = "../../../data/testing/amb_temp.csv" # "amb_temp.csv"
temp = pd.read_csv(temp_path, index_col=[0], parse_dates=True, names=["dt", "temp"])

# %%
df = pd.DataFrame()

# %%
df = power.resample('15T').mean()
df["temp"] = temp.resample('15T').mean()

# %%
df.power.plot()

# %%
train_boundry = int(df.shape[0] * 0.7)

findx = df.index.values[0]
mindx = df.index.values[train_boundry]

# %%
# Split the data
X_train = pd.DataFrame(df.ix[findx:mindx, "temp"])
y_train = pd.DataFrame(df.ix[findx:mindx, "power"])

# %%
print X_train.head(), '\n', y_train.head()
# Out:
#                           temp
# dt
# 2016-07-01 18:30:00  27.983133
# 2016-07-01 18:45:00  28.195467
# 2016-07-01 19:00:00  28.410200
# 2016-07-01 19:15:00  28.741400
# 2016-07-01 19:30:00  28.080967
#                            power
# dt
# 2016-07-01 18:30:00  1126.566667
# 2016-07-01 18:45:00  1136.466667
# 2016-07-01 19:00:00  1082.300000
# 2016-07-01 19:15:00  1139.766667
# 2016-07-01 19:30:00   991.433333

# %%
print X_train.shape, y_train.shape
# Out:
# (538, 1) (538, 1)

# %%
regr = linear_model.LinearRegression()
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print regr.coef_, regr.intercept_
# Out:
# [[ 44.69844185]] [ 38.36665722]

# %%
X_test = pd.DataFrame(df.ix[mindx:, "temp"])
y_test = pd.DataFrame(df.ix[mindx:, "power"])

# %%
fig, ax = plt.subplots()

ax.plot(regr.predict(X_test), color='red')
ax.plot(y_test.values, color='blue')

# %% [markdown]
# # Training data for physical model and SARIMA remains the same

# %%
# Physical Model
x_data = tf.placeholder(shape = [1],dtype = tf.float32)
y_target = tf.placeholder(shape = [1], dtype = tf.float32)

# Coefficients to Learn
A = tf.Variable(tf.random_normal(shape = [1]))
b = tf.Variable(tf.random_normal(shape = [1]))

# Output Variable and Loss Function
output = tf.add(tf.multiply(x_data,A),b)
loss = tf.square(output - y_target)

# Initialisation
init = tf.global_variables_initializer()
sess.run(init)

# Set up Optimiser
my_opt = tf.train.GradientDescentOptimizer(learning_rate = 0.0001)
train_step = my_opt.minimize(loss)

# %% [markdown]
# # !! Random part is a bit confusing?? - Why are we still using single value for prediction and not complete data?

# %%
for i in range(1000):
    index = np.random.choice(60)
    
    x = [df.ix[index, 'temp']]
    y = [df.ix[index, 'temp']]
    
    sess.run(train_step, feed_dict = {x_data : x, y_target : y})
    
    print('Step: ', i+1, "A is: ", sess.run(A), " b is: ", sess.run(b))
    print('Loss: ',sess.run(loss, feed_dict = {x_data : x, y_target : y}))
# Out:
# ('Step: ', 1, 'A is: ', array([ 0.95242786], dtype=float32), ' b is: ', array([-0.63382083], dtype=float32))
# ('Loss: ', array([ 3.69684458], dtype=float32))
# ('Step: ', 2, 'A is: ', array([ 0.96342617], dtype=float32), ' b is: ', array([-0.6334278], dtype=float32))
# ('Loss: ', array([ 2.74538207], dtype=float32))
# ('Step: ', 3, 'A is: ', array([ 0.97240865], dtype=float32), ' b is: ', array([-0.63310039], dtype=float32))
# ('Loss: ', array([ 1.93246424], dtype=float32))
# ('Step: ', 4, 'A is: ', array([ 0.97986996], dtype=float32), ' b is: ', array([-0.63282454], dtype=float32))
# ('Loss: ', array([ 1.38596678], dtype=float32))
# ('Step: ', 5, 'A is: ', array([ 0.98685312], dtype=float32), ' b is: ', array([-0.63258207], dtype=float32))
# ('Loss: ', array([ 1.02245593], dtype=float32))
# ('Step: ', 6, 'A is: ', array([ 0.99268103], dtype=float32), ' b is: ', array([-0.63237977], dtype=float32))
# ('Loss: ', array([ 0.71107745], dtype=float32))
# ('Step: ', 7, 'A is: ', array([ 0.99740577], dtype=float32), ' b is: ', array([-0.63221204], dtype=float32))
# ('Loss: ', array([ 0.49744183], dtype=float32))
# ('Step: ', 8, 'A is: ', array([ 1.00121486], dtype=float32), ' b is: ', array([-0.63207155], dtype=float32))
# ('Loss: ', array([ 0.35896665], dtype=float32))
# ('Step: ', 9, 'A is: ', array([ 1.00457454], dtype=float32), ' b is: ', array([-0.63195199], dtype=float32))
# ('Loss: ', array([ 0.25344884], dtype=float32))
# ('Step: ', 10, 'A is: ', array([ 1.00732851], dtype=float32), ' b is: ', array([-0.63185042], dtype=float32))
# ('Loss: ', array([ 0.18764643], dtype=float32))
# ('Step: ', 11, 'A is: ', array([ 1.00975275], dtype=float32), ' b is: ', array([-0.63176626], dtype=float32))
# ('Loss: ', array([ 0.12303892], dtype=float32))
# ('Step: ', 12, 'A is: ', array([ 1.01175237], dtype=float32), ' b is: ', array([-0.63169354], dtype=float32))
# ('Loss: ', array([ 0.0951736], dtype=float32))
# ('Step: ', 13, 'A is: ', array([ 1.01344562], dtype=float32), ' b is: ', array([-0.63163358], dtype=float32))
# ('Loss: ', array([ 0.06340255], dtype=float32))
# ('Step: ', 14, 'A is: ', array([ 1.01485348], dtype=float32), ' b is: ', array([-0.6315847], dtype=float32))
# ('Loss: ', array([ 0.04155707], dtype=float32))
# ('Step: ', 15, 'A is: ', array([ 1.01608062], dtype=float32), ' b is: ', array([-0.63154006], dtype=float32))
# ('Loss: ', array([ 0.03584336], dtype=float32))
# ('Step: ', 16, 'A is: ', array([ 1.01713049], dtype=float32), ' b is: ', array([-0.63150162], dtype=float32))
# ('Loss: ', array([ 0.02668668], dtype=float32))
# ('Step: ', 17, 'A is: ', array([ 1.01796949], dtype=float32), ' b is: ', array([-0.63147181], dtype=float32))
# ('Loss: ', array([ 0.01568609], dtype=float32))
# ('Step: ', 18, 'A is: ', array([ 1.01872694], dtype=float32), ' b is: ', array([-0.63144422], dtype=float32))
# ('Loss: ', array([ 0.0136994], dtype=float32))
# ('Step: ', 19, 'A is: ', array([ 1.01926053], dtype=float32), ' b is: ', array([-0.63142568], dtype=float32))
# ('Loss: ', array([ 0.00598873], dtype=float32))
# ('Step: ', 20, 'A is: ', array([ 1.01978207], dtype=float32), ' b is: ', array([-0.63140702], dtype=float32))
# ('Loss: ', array([ 0.00620226], dtype=float32))
# ('Step: ', 21, 'A is: ', array([ 1.0201906], dtype=float32), ' b is: ', array([-0.6313926], dtype=float32))
# ('Loss: ', array([ 0.00368396], dtype=float32))
# ('Step: ', 22, 'A is: ', array([ 1.02061546], dtype=float32), ' b is: ', array([-0.6313771], dtype=float32))
# ('Loss: ', array([ 0.00432233], dtype=float32))
# ('Step: ', 23, 'A is: ', array([ 1.02083278], dtype=float32), ' b is: ', array([-0.63136953], dtype=float32))
# ('Loss: ', array([ 0.0009896], dtype=float32))
# ('Step: ', 24, 'A is: ', array([ 1.02116084], dtype=float32), ' b is: ', array([-0.63135755], dtype=float32))
# ('Loss: ', array([ 0.0025768], dtype=float32))
# ('Step: ', 25, 'A is: ', array([ 1.02147043], dtype=float32), ' b is: ', array([-0.63134617], dtype=float32))
# ('Loss: ', array([ 0.00236467], dtype=float32))
# ('Step: ', 26, 'A is: ', array([ 1.02160883], dtype=float32), ' b is: ', array([-0.63134128], dtype=float32))
# ('Loss: ', array([ 0.00042261], dtype=float32))
# ('Step: ', 27, 'A is: ', array([ 1.02184558], dtype=float32), ' b is: ', array([-0.63133258], dtype=float32))
# ('Loss: ', array([ 0.00137442], dtype=float32))
# ('Step: ', 28, 'A is: ', array([ 1.0219239], dtype=float32), ' b is: ', array([-0.63132983], dtype=float32))
# ('Loss: ', array([ 0.0001355], dtype=float32))
# ('Step: ', 29, 'A is: ', array([ 1.02210867], dtype=float32), ' b is: ', array([-0.63132304], dtype=float32))
# ('Loss: ', array([ 0.00083302], dtype=float32))
# ('Step: ', 30, 'A is: ', array([ 1.02207804], dtype=float32), ' b is: ', array([-0.63132411], dtype=float32))
# ('Loss: ', array([  1.97671798e-05], dtype=float32))
# ('Step: ', 31, 'A is: ', array([ 1.02212882], dtype=float32), ' b is: ', array([-0.63132232], dtype=float32))
# ('Loss: ', array([  5.74245096e-05], dtype=float32))
# ('Step: ', 32, 'A is: ', array([ 1.02217722], dtype=float32), ' b is: ', array([-0.6313206], dtype=float32))
# ('Loss: ', array([  5.24495008e-05], dtype=float32))
# ('Step: ', 33, 'A is: ', array([ 1.02228975], dtype=float32), ' b is: ', array([-0.63131648], dtype=float32))
# ('Loss: ', array([ 0.00029974], dtype=float32))
# ('Step: ', 34, 'A is: ', array([ 1.02233779], dtype=float32), ' b is: ', array([-0.63131475], dtype=float32))
# ('Loss: ', array([  5.27815464e-05], dtype=float32))
# ('Step: ', 35, 'A is: ', array([ 1.02232945], dtype=float32), ' b is: ', array([-0.63131505], dtype=float32))
# ('Loss: ', array([  1.50880078e-06], dtype=float32))
# ('Step: ', 36, 'A is: ', array([ 1.02244473], dtype=float32), ' b is: ', array([-0.63131082], dtype=float32))
# ('Loss: ', array([ 0.00032193], dtype=float32))
# ('Step: ', 37, 'A is: ', array([ 1.02251661], dtype=float32), ' b is: ', array([-0.6313082], dtype=float32))
# ('Loss: ', array([ 0.00012217], dtype=float32))
# ('Step: ', 38, 'A is: ', array([ 1.02241611], dtype=float32), ' b is: ', array([-0.63131171], dtype=float32))
# ('Loss: ', array([ 0.00021146], dtype=float32))
# ('Step: ', 39, 'A is: ', array([ 1.02254426], dtype=float32), ' b is: ', array([-0.63130701], dtype=float32))
# ('Loss: ', array([ 0.00040622], dtype=float32))
# ('Step: ', 40, 'A is: ', array([ 1.02243912], dtype=float32), ' b is: ', array([-0.63131064], dtype=float32))
# ('Loss: ', array([ 0.0002312], dtype=float32))
# ('Step: ', 41, 'A is: ', array([ 1.02256572], dtype=float32), ' b is: ', array([-0.63130599], dtype=float32))
# ('Loss: ', array([ 0.00039682], dtype=float32))
# ('Step: ', 42, 'A is: ', array([ 1.02254486], dtype=float32), ' b is: ', array([-0.63130671], dtype=float32))
# ('Loss: ', array([  9.71324334e-06], dtype=float32))
# ('Step: ', 43, 'A is: ', array([ 1.02262235], dtype=float32), ' b is: ', array([-0.63130391], dtype=float32))
# ('Loss: ', array([ 0.00014453], dtype=float32))
# ('Step: ', 44, 'A is: ', array([ 1.0227201], dtype=float32), ' b is: ', array([-0.63130027], dtype=float32))
# ('Loss: ', array([ 0.00023657], dtype=float32))
# ('Step: ', 45, 'A is: ', array([ 1.02261937], dtype=float32), ' b is: ', array([-0.63130379], dtype=float32))
# ('Loss: ', array([ 0.00021777], dtype=float32))
# ('Step: ', 46, 'A is: ', array([ 1.02256167], dtype=float32), ' b is: ', array([-0.63130581], dtype=float32))
# ('Loss: ', array([  7.26900907e-05], dtype=float32))
# ('Step: ', 47, 'A is: ', array([ 1.02253556], dtype=float32), ' b is: ', array([-0.63130677], dtype=float32))
# ('Loss: ', array([  1.52290013e-05], dtype=float32))
# ('Step: ', 48, 'A is: ', array([ 1.02251947], dtype=float32), ' b is: ', array([-0.63130736], dtype=float32))
# ('Loss: ', array([  5.76649109e-06], dtype=float32))
# ('Step: ', 49, 'A is: ', array([ 1.02261567], dtype=float32), ' b is: ', array([-0.63130385], dtype=float32))
# ('Loss: ', array([ 0.00022578], dtype=float32))
# ('Step: ', 50, 'A is: ', array([ 1.02271628], dtype=float32), ' b is: ', array([-0.63130015], dtype=float32))
# ('Loss: ', array([ 0.0002508], dtype=float32))
# ('Step: ', 51, 'A is: ', array([ 1.0226512], dtype=float32), ' b is: ', array([-0.63130248], dtype=float32))
# ('Loss: ', array([  9.30717360e-05], dtype=float32))
# ('Step: ', 52, 'A is: ', array([ 1.02253044], dtype=float32), ' b is: ', array([-0.63130665], dtype=float32))
# ('Loss: ', array([ 0.00030598], dtype=float32))
# ('Step: ', 53, 'A is: ', array([ 1.02247906], dtype=float32), ' b is: ', array([-0.63130844], dtype=float32))
# ('Loss: ', array([  5.74823389e-05], dtype=float32))
# ('Step: ', 54, 'A is: ', array([ 1.0225997], dtype=float32), ' b is: ', array([-0.63130397], dtype=float32))
# ('Loss: ', array([ 0.00036097], dtype=float32))
# ('Step: ', 55, 'A is: ', array([ 1.02259934], dtype=float32), ' b is: ', array([-0.63130397], dtype=float32))
# ('Loss: ', array([  2.85217538e-09], dtype=float32))
# ('Step: ', 56, 'A is: ', array([ 1.02270043], dtype=float32), ' b is: ', array([-0.63130021], dtype=float32))
# ('Loss: ', array([ 0.0002531], dtype=float32))
# ('Step: ', 57, 'A is: ', array([ 1.02274692], dtype=float32), ' b is: ', array([-0.63129854], dtype=float32))
# ('Loss: ', array([  5.16239706e-05], dtype=float32))
# ('Step: ', 58, 'A is: ', array([ 1.02267694], dtype=float32), ' b is: ', array([-0.63130099], dtype=float32))
# ('Loss: ', array([ 0.00010766], dtype=float32))
# ('Step: ', 59, 'A is: ', array([ 1.02262831], dtype=float32), ' b is: ', array([-0.63130271], dtype=float32))
# ('Loss: ', array([  5.23390518e-05], dtype=float32))
# ('Step: ', 60, 'A is: ', array([ 1.02256918], dtype=float32), ' b is: ', array([-0.6313048], dtype=float32))
# ('Loss: ', array([  7.63783610e-05], dtype=float32))
# ('Step: ', 61, 'A is: ', array([ 1.0225054], dtype=float32), ' b is: ', array([-0.63130707], dtype=float32))
# ('Loss: ', array([  8.82414461e-05], dtype=float32))
# ('Step: ', 62, 'A is: ', array([ 1.02247417], dtype=float32), ' b is: ', array([-0.6313082], dtype=float32))
# ('Loss: ', array([  2.14642241e-05], dtype=float32))
# ('Step: ', 63, 'A is: ', array([ 1.02259552], dtype=float32), ' b is: ', array([-0.63130373], dtype=float32))
# ('Loss: ', array([ 0.00036525], dtype=float32))
# ('Step: ', 64, 'A is: ', array([ 1.02253151], dtype=float32), ' b is: ', array([-0.63130599], dtype=float32))
# ('Loss: ', array([  8.87797796e-05], dtype=float32))
# ('Step: ', 65, 'A is: ', array([ 1.02263153], dtype=float32), ' b is: ', array([-0.6313023], dtype=float32))
# ('Loss: ', array([ 0.00024527], dtype=float32))
# ('Step: ', 66, 'A is: ', array([ 1.02256382], dtype=float32), ' b is: ', array([-0.63130468], dtype=float32))
# ('Loss: ', array([  9.98901669e-05], dtype=float32))
# ('Step: ', 67, 'A is: ', array([ 1.0225631], dtype=float32), ' b is: ', array([-0.63130468], dtype=float32))
# ('Loss: ', array([  1.14087015e-08], dtype=float32))
# ('Step: ', 68, 'A is: ', array([ 1.02253866], dtype=float32), ' b is: ', array([-0.63130558], dtype=float32))
# ('Loss: ', array([  1.32717105e-05], dtype=float32))
# ('Step: ', 69, 'A is: ', array([ 1.02260184], dtype=float32), ' b is: ', array([-0.63130325], dtype=float32))
# ('Loss: ', array([  9.51068359e-05], dtype=float32))
# ('Step: ', 70, 'A is: ', array([ 1.02264977], dtype=float32), ' b is: ', array([-0.63130152], dtype=float32))
# ('Loss: ', array([  5.44574905e-05], dtype=float32))
# ('Step: ', 71, 'A is: ', array([ 1.0225271], dtype=float32), ' b is: ', array([-0.63130575], dtype=float32))
# ('Loss: ', array([ 0.00031492], dtype=float32))
# ('Step: ', 72, 'A is: ', array([ 1.02250242], dtype=float32), ' b is: ', array([-0.63130665], dtype=float32))
# ('Loss: ', array([  1.35370683e-05], dtype=float32))
# ('Step: ', 73, 'A is: ', array([ 1.02239799], dtype=float32), ' b is: ', array([-0.63131028], dtype=float32))
# ('Loss: ', array([ 0.00022739], dtype=float32))
# ('Step: ', 74, 'A is: ', array([ 1.02239192], dtype=float32), ' b is: ', array([-0.63131052], dtype=float32))
# ('Loss: ', array([  8.24278686e-07], dtype=float32))
# ('Step: ', 75, 'A is: ', array([ 1.02240455], dtype=float32), ' b is: ', array([-0.63131005], dtype=float32))
# ('Loss: ', array([  3.55838347e-06], dtype=float32))
# ('Step: ', 76, 'A is: ', array([ 1.0224191], dtype=float32), ' b is: ', array([-0.63130951], dtype=float32))
# ('Loss: ', array([  4.75283377e-06], dtype=float32))
# ('Step: ', 77, 'A is: ', array([ 1.02252841], dtype=float32), ' b is: ', array([-0.63130552], dtype=float32))
# ('Loss: ', array([ 0.00029115], dtype=float32))
# ('Step: ', 78, 'A is: ', array([ 1.02253914], dtype=float32), ' b is: ', array([-0.63130516], dtype=float32))
# ('Loss: ', array([  2.65323615e-06], dtype=float32))
# ('Step: ', 79, 'A is: ', array([ 1.02245772], dtype=float32), ' b is: ', array([-0.63130802], dtype=float32))
# ('Loss: ', array([ 0.00014129], dtype=float32))
# ('Step: ', 80, 'A is: ', array([ 1.0223732], dtype=float32), ' b is: ', array([-0.63131094], dtype=float32))
# ('Loss: ', array([ 0.00015041], dtype=float32))
# ('Step: ', 81, 'A is: ', array([ 1.02238476], dtype=float32), ' b is: ', array([-0.63131052], dtype=float32))
# ('Loss: ', array([  3.02586704e-06], dtype=float32))
# ('Step: ', 82, 'A is: ', array([ 1.02246571], dtype=float32), ' b is: ', array([-0.6313076], dtype=float32))
# ('Loss: ', array([ 0.00015517], dtype=float32))
# ('Step: ', 83, 'A is: ', array([ 1.02254748], dtype=float32), ' b is: ', array([-0.63130462], dtype=float32))
# ('Loss: ', array([ 0.00016035], dtype=float32))
# ('Step: ', 84, 'A is: ', array([ 1.02260935], dtype=float32), ' b is: ', array([-0.63130236], dtype=float32))
# ('Loss: ', array([  9.10950475e-05], dtype=float32))
# ('Step: ', 85, 'A is: ', array([ 1.0226562], dtype=float32), ' b is: ', array([-0.63130069], dtype=float32))
# ('Loss: ', array([  5.18434717e-05], dtype=float32))
# ('Step: ', 86, 'A is: ', array([ 1.02274704], dtype=float32), ' b is: ', array([-0.63129735], dtype=float32))
# ('Loss: ', array([ 0.00020404], dtype=float32))
# ('Step: ', 87, 'A is: ', array([ 1.0227176], dtype=float32), ' b is: ', array([-0.63129842], dtype=float32))
# ('Loss: ', array([  1.96824694e-05], dtype=float32))
# ('Step: ', 88, 'A is: ', array([ 1.02262962], dtype=float32), ' b is: ', array([-0.63130152], dtype=float32))
# ('Loss: ', array([ 0.00016733], dtype=float32))
# ('Step: ', 89, 'A is: ', array([ 1.02260864], dtype=float32), ' b is: ', array([-0.6313023], dtype=float32))
# ('Loss: ', array([  9.90439730e-06], dtype=float32))
# ('Step: ', 90, 'A is: ', array([ 1.02251577], dtype=float32), ' b is: ', array([-0.63130552], dtype=float32))
# ('Loss: ', array([ 0.00018365], dtype=float32))
# ('Step: ', 91, 'A is: ', array([ 1.02242982], dtype=float32), ' b is: ', array([-0.6313085], dtype=float32))
# ('Loss: ', array([ 0.00015613], dtype=float32))
# ('Step: ', 92, 'A is: ', array([ 1.02236629], dtype=float32), ' b is: ', array([-0.6313107], dtype=float32))
# ('Loss: ', array([  8.58215499e-05], dtype=float32))
# ('Step: ', 93, 'A is: ', array([ 1.02244997], dtype=float32), ' b is: ', array([-0.63130766], dtype=float32))
# ('Loss: ', array([ 0.00016615], dtype=float32))
# ('Step: ', 94, 'A is: ', array([ 1.02252102], dtype=float32), ' b is: ', array([-0.6313051], dtype=float32))
# ('Loss: ', array([ 0.00011949], dtype=float32))
# ('Step: ', 95, 'A is: ', array([ 1.02259076], dtype=float32), ' b is: ', array([-0.63130254], dtype=float32))
# ('Loss: ', array([ 0.00011593], dtype=float32))
# ('Step: ', 96, 'A is: ', array([ 1.0225234], dtype=float32), ' b is: ', array([-0.63130492], dtype=float32))
# ('Loss: ', array([  9.81440680e-05], dtype=float32))
# ('Step: ', 97, 'A is: ', array([ 1.02263391], dtype=float32), ' b is: ', array([-0.63130087], dtype=float32))
# ('Loss: ', array([ 0.00030119], dtype=float32))
# ('Step: ', 98, 'A is: ', array([ 1.02259016], dtype=float32), ' b is: ', array([-0.63130242], dtype=float32))
# ('Loss: ', array([  4.24269274e-05], dtype=float32))
# ('Step: ', 99, 'A is: ', array([ 1.02252913], dtype=float32), ' b is: ', array([-0.63130456], dtype=float32))
# ('Loss: ', array([  8.11514037e-05], dtype=float32))
# ('Step: ', 100, 'A is: ', array([ 1.02264237], dtype=float32), ' b is: ', array([-0.63130039], dtype=float32))
# ('Loss: ', array([ 0.00031825], dtype=float32))
# ('Step: ', 101, 'A is: ', array([ 1.02262735], dtype=float32), ' b is: ', array([-0.63130093], dtype=float32))
# ('Loss: ', array([  5.13443956e-06], dtype=float32))
# ('Step: ', 102, 'A is: ', array([ 1.02259672], dtype=float32), ' b is: ', array([-0.631302], dtype=float32))
# ('Loss: ', array([  2.09896971e-05], dtype=float32))
# ('Step: ', 103, 'A is: ', array([ 1.02269828], dtype=float32), ' b is: ', array([-0.63129824], dtype=float32))
# ('Loss: ', array([ 0.00025487], dtype=float32))
# ('Step: ', 104, 'A is: ', array([ 1.0227679], dtype=float32), ' b is: ', array([-0.63129568], dtype=float32))
# ('Loss: ', array([ 0.00011816], dtype=float32))
# ('Step: ', 105, 'A is: ', array([ 1.02268636], dtype=float32), ' b is: ', array([-0.63129854], dtype=float32))
# ('Loss: ', array([ 0.00014568], dtype=float32))
# ('Step: ', 106, 'A is: ', array([ 1.02260971], dtype=float32), ' b is: ', array([-0.63130122], dtype=float32))
# ('Loss: ', array([ 0.00012767], dtype=float32))
# ('Step: ', 107, 'A is: ', array([ 1.02271676], dtype=float32), ' b is: ', array([-0.63129729], dtype=float32))
# ('Loss: ', array([ 0.00028526], dtype=float32))
# ('Step: ', 108, 'A is: ', array([ 1.02266788], dtype=float32), ' b is: ', array([-0.63129902], dtype=float32))
# ('Loss: ', array([  5.31146397e-05], dtype=float32))
# ('Step: ', 109, 'A is: ', array([ 1.02257562], dtype=float32), ' b is: ', array([-0.63130224], dtype=float32))
# ('Loss: ', array([ 0.00018246], dtype=float32))
# ('Step: ', 110, 'A is: ', array([ 1.02263319], dtype=float32), ' b is: ', array([-0.63130015], dtype=float32))
# ('Loss: ', array([  7.89669866e-05], dtype=float32))
# ('Step: ', 111, 'A is: ', array([ 1.02255285], dtype=float32), ' b is: ', array([-0.63130295], dtype=float32))
# ('Loss: ', array([ 0.0001393], dtype=float32))
# ('Step: ', 112, 'A is: ', array([ 1.02245247], dtype=float32), ' b is: ', array([-0.63130647], dtype=float32))
# ('Loss: ', array([ 0.00021174], dtype=float32))
# ('Step: ', 113, 'A is: ', array([ 1.02252305], dtype=float32), ' b is: ', array([-0.63130391], dtype=float32))
# ('Loss: ', array([ 0.0001182], dtype=float32))
# ('Step: ', 114, 'A is: ', array([ 1.02252674], dtype=float32), ' b is: ', array([-0.63130379], dtype=float32))
# ('Loss: ', array([  3.08067683e-07], dtype=float32))
# ('Step: ', 115, 'A is: ', array([ 1.02253187], dtype=float32), ' b is: ', array([-0.63130361], dtype=float32))
# ('Loss: ', array([  5.87911927e-07], dtype=float32))
# ('Step: ', 116, 'A is: ', array([ 1.02264297], dtype=float32), ' b is: ', array([-0.6312995], dtype=float32))
# ('Loss: ', array([ 0.00030505], dtype=float32))
# ('Step: ', 117, 'A is: ', array([ 1.02264178], dtype=float32), ' b is: ', array([-0.63129956], dtype=float32))
# ('Loss: ', array([  3.63797881e-08], dtype=float32))
# ('Step: ', 118, 'A is: ', array([ 1.02256], dtype=float32), ' b is: ', array([-0.63130242], dtype=float32))
# ('Loss: ', array([ 0.00014421], dtype=float32))
# ('Step: ', 119, 'A is: ', array([ 1.02249146], dtype=float32), ' b is: ', array([-0.6313048], dtype=float32))
# ('Loss: ', array([ 0.000101], dtype=float32))
# ('Step: ', 120, 'A is: ', array([ 1.02256], dtype=float32), ' b is: ', array([-0.6313023], dtype=float32))
# ('Loss: ', array([ 0.00011145], dtype=float32))
# ('Step: ', 121, 'A is: ', array([ 1.02255988], dtype=float32), ' b is: ', array([-0.6313023], dtype=float32))
# ('Loss: ', array([  3.63797881e-10], dtype=float32))
# ('Step: ', 122, 'A is: ', array([ 1.02265], dtype=float32), ' b is: ', array([-0.63129896], dtype=float32))
# ('Loss: ', array([ 0.00019841], dtype=float32))
# ('Step: ', 123, 'A is: ', array([ 1.0227325], dtype=float32), ' b is: ', array([-0.63129592], dtype=float32))
# ('Loss: ', array([ 0.00016664], dtype=float32))
# ('Step: ', 124, 'A is: ', array([ 1.02266073], dtype=float32), ' b is: ', array([-0.63129842], dtype=float32))
# ('Loss: ', array([ 0.00011299], dtype=float32))
# ('Step: ', 125, 'A is: ', array([ 1.02256966], dtype=float32), ' b is: ', array([-0.63130158], dtype=float32))
# ('Loss: ', array([ 0.0001779], dtype=float32))
# ('Step: ', 126, 'A is: ', array([ 1.02262247], dtype=float32), ' b is: ', array([-0.63129967], dtype=float32))
# ('Loss: ', array([  6.61136000e-05], dtype=float32))
# ('Step: ', 127, 'A is: ', array([ 1.02258658], dtype=float32), ' b is: ', array([-0.63130093], dtype=float32))
# ('Loss: ', array([  2.86033028e-05], dtype=float32))
# ('Step: ', 128, 'A is: ', array([ 1.02251375], dtype=float32), ' b is: ', array([-0.63130349], dtype=float32))
# ('Loss: ', array([ 0.00011421], dtype=float32))
# ('Step: ', 129, 'A is: ', array([ 1.02260149], dtype=float32), ' b is: ', array([-0.63130027], dtype=float32))
# ('Loss: ', array([ 0.00018624], dtype=float32))
# ('Step: ', 130, 'A is: ', array([ 1.02256286], dtype=float32), ' b is: ', array([-0.63130164], dtype=float32))
# ('Loss: ', array([  3.29823561e-05], dtype=float32))
# ('Step: ', 131, 'A is: ', array([ 1.02261674], dtype=float32), ' b is: ', array([-0.63129967], dtype=float32))
# ('Loss: ', array([  6.86814892e-05], dtype=float32))
# ('Step: ', 132, 'A is: ', array([ 1.02272272], dtype=float32), ' b is: ', array([-0.63129574], dtype=float32))
# ('Loss: ', array([ 0.00027974], dtype=float32))
# ('Step: ', 133, 'A is: ', array([ 1.0227735], dtype=float32), ' b is: ', array([-0.63129389], dtype=float32))
# ('Loss: ', array([  6.20225910e-05], dtype=float32))
# ('Step: ', 134, 'A is: ', array([ 1.02280509], dtype=float32), ' b is: ', array([-0.63129276], dtype=float32))
# ('Loss: ', array([  2.37302302e-05], dtype=float32))
# ('Step: ', 135, 'A is: ', array([ 1.02283573], dtype=float32), ' b is: ', array([-0.63129163], dtype=float32))
# ('Loss: ', array([  2.25015137e-05], dtype=float32))
# ('Step: ', 136, 'A is: ', array([ 1.02268434], dtype=float32), ' b is: ', array([-0.63129687], dtype=float32))
# ('Loss: ', array([ 0.00048104], dtype=float32))
# ('Step: ', 137, 'A is: ', array([ 1.02275229], dtype=float32), ' b is: ', array([-0.63129437], dtype=float32))
# ('Loss: ', array([ 0.00011214], dtype=float32))
# ('Step: ', 138, 'A is: ', array([ 1.02272809], dtype=float32), ' b is: ', array([-0.63129526], dtype=float32))
# ('Loss: ', array([  1.33831199e-05], dtype=float32))
# ('Step: ', 139, 'A is: ', array([ 1.0227077], dtype=float32), ' b is: ', array([-0.63129598], dtype=float32))
# ('Loss: ', array([  9.53572817e-06], dtype=float32))
# ('Step: ', 140, 'A is: ', array([ 1.02268243], dtype=float32), ' b is: ', array([-0.63129687], dtype=float32))
# ('Loss: ', array([  1.45373670e-05], dtype=float32))
# ('Step: ', 141, 'A is: ', array([ 1.02273154], dtype=float32), ' b is: ', array([-0.63129508], dtype=float32))
# ('Loss: ', array([  5.78879590e-05], dtype=float32))
# ('Step: ', 142, 'A is: ', array([ 1.02278662], dtype=float32), ' b is: ', array([-0.63129306], dtype=float32))
# ('Loss: ', array([  7.36036018e-05], dtype=float32))
# ('Step: ', 143, 'A is: ', array([ 1.0227164], dtype=float32), ' b is: ', array([-0.63129556], dtype=float32))
# ('Loss: ', array([ 0.00010893], dtype=float32))
# ('Step: ', 144, 'A is: ', array([ 1.02270377], dtype=float32), ' b is: ', array([-0.63129604], dtype=float32))
# ('Loss: ', array([  3.69641930e-06], dtype=float32))
# ('Step: ', 145, 'A is: ', array([ 1.02278948], dtype=float32), ' b is: ', array([-0.63129288], dtype=float32))
# ('Loss: ', array([ 0.0001819], dtype=float32))
# ('Step: ', 146, 'A is: ', array([ 1.02281463], dtype=float32), ' b is: ', array([-0.63129199], dtype=float32))
# ('Loss: ', array([  1.51249733e-05], dtype=float32))
# ('Step: ', 147, 'A is: ', array([ 1.02274203], dtype=float32), ' b is: ', array([-0.63129455], dtype=float32))
# ('Loss: ', array([ 0.00011687], dtype=float32))
# ('Step: ', 148, 'A is: ', array([ 1.02267289], dtype=float32), ' b is: ', array([-0.63129699], dtype=float32))
# ('Loss: ', array([ 0.00010542], dtype=float32))
# ('Step: ', 149, 'A is: ', array([ 1.02270997], dtype=float32), ' b is: ', array([-0.63129562], dtype=float32))
# ('Loss: ', array([  3.26763584e-05], dtype=float32))
# ('Step: ', 150, 'A is: ', array([ 1.0227778], dtype=float32), ' b is: ', array([-0.63129312], dtype=float32))
# ('Loss: ', array([ 0.0001123], dtype=float32))
# ('Step: ', 151, 'A is: ', array([ 1.02268636], dtype=float32), ' b is: ', array([-0.63129634], dtype=float32))
# ('Loss: ', array([ 0.00018184], dtype=float32))
# ('Step: ', 152, 'A is: ', array([ 1.02272534], dtype=float32), ' b is: ', array([-0.63129491], dtype=float32))
# ('Loss: ', array([  3.60062259e-05], dtype=float32))
# ('Step: ', 153, 'A is: ', array([ 1.02280414], dtype=float32), ' b is: ', array([-0.63129199], dtype=float32))
# ('Loss: ', array([ 0.00015318], dtype=float32))
# ('Step: ', 154, 'A is: ', array([ 1.02271676], dtype=float32), ' b is: ', array([-0.63129508], dtype=float32))
# ('Loss: ', array([ 0.00016733], dtype=float32))
# ('Step: ', 155, 'A is: ', array([ 1.02280247], dtype=float32), ' b is: ', array([-0.63129193], dtype=float32))
# ('Loss: ', array([ 0.0001821], dtype=float32))
# ('Step: ', 156, 'A is: ', array([ 1.02286232], dtype=float32), ' b is: ', array([-0.63128972], dtype=float32))
# ('Loss: ', array([  8.78477149e-05], dtype=float32))
# ('Step: ', 157, 'A is: ', array([ 1.02281272], dtype=float32), ' b is: ', array([-0.63129151], dtype=float32))
# ('Loss: ', array([  5.57031635e-05], dtype=float32))
# ('Step: ', 158, 'A is: ', array([ 1.02282858], dtype=float32), ' b is: ', array([-0.63129091], dtype=float32))
# ('Loss: ', array([  5.96978134e-06], dtype=float32))
# ('Step: ', 159, 'A is: ', array([ 1.02269101], dtype=float32), ' b is: ', array([-0.63129568], dtype=float32))
# ('Loss: ', array([ 0.00040017], dtype=float32))
# ('Step: ', 160, 'A is: ', array([ 1.02278054], dtype=float32), ' b is: ', array([-0.6312924], dtype=float32))
# ('Loss: ', array([ 0.00019846], dtype=float32))
# ('Step: ', 161, 'A is: ', array([ 1.02285492], dtype=float32), ' b is: ', array([-0.63128966], dtype=float32))
# ('Loss: ', array([ 0.00013715], dtype=float32))
# ('Step: ', 162, 'A is: ', array([ 1.02289939], dtype=float32), ' b is: ', array([-0.63128805], dtype=float32))
# ('Loss: ', array([  4.80429881e-05], dtype=float32))
# ('Step: ', 163, 'A is: ', array([ 1.02281535], dtype=float32), ' b is: ', array([-0.63129103], dtype=float32))
# ('Loss: ', array([ 0.00015684], dtype=float32))
# ('Step: ', 164, 'A is: ', array([ 1.02289224], dtype=float32), ' b is: ', array([-0.63128817], dtype=float32))
# ('Loss: ', array([ 0.00014725], dtype=float32))
# ('Step: ', 165, 'A is: ', array([ 1.02280521], dtype=float32), ' b is: ', array([-0.63129127], dtype=float32))
# ('Loss: ', array([ 0.00016773], dtype=float32))
# ('Step: ', 166, 'A is: ', array([ 1.02287793], dtype=float32), ' b is: ', array([-0.63128859], dtype=float32))
# ('Loss: ', array([ 0.00013101], dtype=float32))
# ('Step: ', 167, 'A is: ', array([ 1.02275133], dtype=float32), ' b is: ', array([-0.631293], dtype=float32))
# ('Loss: ', array([ 0.00034364], dtype=float32))
# ('Step: ', 168, 'A is: ', array([ 1.02279007], dtype=float32), ' b is: ', array([-0.63129157], dtype=float32))
# ('Loss: ', array([  3.59375881e-05], dtype=float32))
# ('Step: ', 169, 'A is: ', array([ 1.02281904], dtype=float32), ' b is: ', array([-0.6312905], dtype=float32))
# ('Loss: ', array([  2.01249495e-05], dtype=float32))
# ('Step: ', 170, 'A is: ', array([ 1.02267039], dtype=float32), ' b is: ', array([-0.63129568], dtype=float32))
# ('Loss: ', array([ 0.00046363], dtype=float32))
# ('Step: ', 171, 'A is: ', array([ 1.02270794], dtype=float32), ' b is: ', array([-0.63129431], dtype=float32))
# ('Loss: ', array([  3.32897798e-05], dtype=float32))
# ('Step: ', 172, 'A is: ', array([ 1.02268457], dtype=float32), ' b is: ', array([-0.63129514], dtype=float32))
# ('Loss: ', array([  1.23703503e-05], dtype=float32))
# ('Step: ', 173, 'A is: ', array([ 1.02277505], dtype=float32), ' b is: ', array([-0.63129181], dtype=float32))
# ('Loss: ', array([ 0.00020268], dtype=float32))
# ('Step: ', 174, 'A is: ', array([ 1.02266526], dtype=float32), ' b is: ', array([-0.63129562], dtype=float32))
# ('Loss: ', array([ 0.00025841], dtype=float32))
# ('Step: ', 175, 'A is: ', array([ 1.02262259], dtype=float32), ' b is: ', array([-0.63129711], dtype=float32))
# ('Loss: ', array([  4.05352475e-05], dtype=float32))
# ('Step: ', 176, 'A is: ', array([ 1.02272022], dtype=float32), ' b is: ', array([-0.63129354], dtype=float32))
# ('Loss: ', array([ 0.0002361], dtype=float32))
# ('Step: ', 177, 'A is: ', array([ 1.02280354], dtype=float32), ' b is: ', array([-0.63129044], dtype=float32))
# ('Loss: ', array([ 0.0001717], dtype=float32))
# ('Step: ', 178, 'A is: ', array([ 1.02287459], dtype=float32), ' b is: ', array([-0.63128781], dtype=float32))
# ('Loss: ', array([ 0.00012488], dtype=float32))
# ('Step: ', 179, 'A is: ', array([ 1.02275491], dtype=float32), ' b is: ', array([-0.63129199], dtype=float32))
# ('Loss: ', array([ 0.00030886], dtype=float32))
# ('Step: ', 180, 'A is: ', array([ 1.02282178], dtype=float32), ' b is: ', array([-0.63128954], dtype=float32))
# ('Loss: ', array([ 0.00010973], dtype=float32))
# ('Step: ', 181, 'A is: ', array([ 1.02275217], dtype=float32), ' b is: ', array([-0.63129199], dtype=float32))
# ('Loss: ', array([ 0.00010778], dtype=float32))
# ('Step: ', 182, 'A is: ', array([ 1.02281952], dtype=float32), ' b is: ', array([-0.63128948], dtype=float32))
# ('Loss: ', array([ 0.00011097], dtype=float32))
# ('Step: ', 183, 'A is: ', array([ 1.0228343], dtype=float32), ' b is: ', array([-0.63128895], dtype=float32))
# ('Loss: ', array([  5.21252878e-06], dtype=float32))
# ('Step: ', 184, 'A is: ', array([ 1.022874], dtype=float32), ' b is: ', array([-0.63128752], dtype=float32))
# ('Loss: ', array([  3.82608014e-05], dtype=float32))
# ('Step: ', 185, 'A is: ', array([ 1.02293277], dtype=float32), ' b is: ', array([-0.63128537], dtype=float32))
# ('Loss: ', array([  8.52570520e-05], dtype=float32))
# ('Step: ', 186, 'A is: ', array([ 1.02284122], dtype=float32), ' b is: ', array([-0.63128859], dtype=float32))
# ('Loss: ', array([ 0.00018541], dtype=float32))
# ('Step: ', 187, 'A is: ', array([ 1.02288771], dtype=float32), ' b is: ', array([-0.63128686], dtype=float32))
# ('Loss: ', array([  5.25324140e-05], dtype=float32))
# ('Step: ', 188, 'A is: ', array([ 1.0228076], dtype=float32), ' b is: ', array([-0.63128972], dtype=float32))
# ('Loss: ', array([ 0.0001427], dtype=float32))
# ('Step: ', 189, 'A is: ', array([ 1.02271128], dtype=float32), ' b is: ', array([-0.63129312], dtype=float32))
# ('Loss: ', array([ 0.00020154], dtype=float32))
# ('Step: ', 190, 'A is: ', array([ 1.02260149], dtype=float32), ' b is: ', array([-0.63129693], dtype=float32))
# ('Loss: ', array([ 0.00025651], dtype=float32))
# ('Step: ', 191, 'A is: ', array([ 1.02270043], dtype=float32), ' b is: ', array([-0.6312933], dtype=float32))
# ('Loss: ', array([ 0.00024164], dtype=float32))
# ('Step: ', 192, 'A is: ', array([ 1.02262151], dtype=float32), ' b is: ', array([-0.6312961], dtype=float32))
# ('Loss: ', array([ 0.0001355], dtype=float32))
# ('Step: ', 193, 'A is: ', array([ 1.02260971], dtype=float32), ' b is: ', array([-0.63129652], dtype=float32))
# ('Loss: ', array([  3.15325815e-06], dtype=float32))
# ('Step: ', 194, 'A is: ', array([ 1.02257788], dtype=float32), ' b is: ', array([-0.63129765], dtype=float32))
# ('Loss: ', array([  2.26102165e-05], dtype=float32))
# ('Step: ', 195, 'A is: ', array([ 1.02263892], dtype=float32), ' b is: ', array([-0.63129544], dtype=float32))
# ('Loss: ', array([  8.91035597e-05], dtype=float32))
# ('Step: ', 196, 'A is: ', array([ 1.02271354], dtype=float32), ' b is: ', array([-0.6312927], dtype=float32))
# ('Loss: ', array([ 0.00013559], dtype=float32))
# ('Step: ', 197, 'A is: ', array([ 1.02277899], dtype=float32), ' b is: ', array([-0.63129032], dtype=float32))
# ('Loss: ', array([ 0.00010436], dtype=float32))
# ('Step: ', 198, 'A is: ', array([ 1.02284229], dtype=float32), ' b is: ', array([-0.63128799], dtype=float32))
# ('Loss: ', array([  9.83331120e-05], dtype=float32))
# ('Step: ', 199, 'A is: ', array([ 1.02270246], dtype=float32), ' b is: ', array([-0.63129288], dtype=float32))
# ('Loss: ', array([ 0.00041356], dtype=float32))
# ('Step: ', 200, 'A is: ', array([ 1.02263546], dtype=float32), ' b is: ', array([-0.63129526], dtype=float32))
# ('Loss: ', array([  9.83331120e-05], dtype=float32))
# ('Step: ', 201, 'A is: ', array([ 1.02268398], dtype=float32), ' b is: ', array([-0.63129348], dtype=float32))
# ('Loss: ', array([  5.60167828e-05], dtype=float32))
# ('Step: ', 202, 'A is: ', array([ 1.02264428], dtype=float32), ' b is: ', array([-0.63129491], dtype=float32))
# ('Loss: ', array([  3.51416529e-05], dtype=float32))
# ('Step: ', 203, 'A is: ', array([ 1.02257442], dtype=float32), ' b is: ', array([-0.63129735], dtype=float32))
# ('Loss: ', array([ 0.00010612], dtype=float32))
# ('Step: ', 204, 'A is: ', array([ 1.02263224], dtype=float32), ' b is: ', array([-0.63129526], dtype=float32))
# ('Loss: ', array([  7.93742947e-05], dtype=float32))
# ('Step: ', 205, 'A is: ', array([ 1.02258468], dtype=float32), ' b is: ', array([-0.63129693], dtype=float32))
# ('Loss: ', array([  4.99925554e-05], dtype=float32))
# ('Step: ', 206, 'A is: ', array([ 1.02256072], dtype=float32), ' b is: ', array([-0.63129777], dtype=float32))
# ('Loss: ', array([  1.27624990e-05], dtype=float32))
# ('Step: ', 207, 'A is: ', array([ 1.02267492], dtype=float32), ' b is: ', array([-0.63129354], dtype=float32))
# ('Loss: ', array([ 0.00032461], dtype=float32))
# ('Step: ', 208, 'A is: ', array([ 1.02260005], dtype=float32), ' b is: ', array([-0.63129616], dtype=float32))
# ('Loss: ', array([ 0.00012171], dtype=float32))
# ('Step: ', 209, 'A is: ', array([ 1.02253115], dtype=float32), ' b is: ', array([-0.6312986], dtype=float32))
# ('Loss: ', array([ 0.00010273], dtype=float32))
# ('Step: ', 210, 'A is: ', array([ 1.02262187], dtype=float32), ' b is: ', array([-0.63129526], dtype=float32))
# ('Loss: ', array([ 0.00020019], dtype=float32))
# ('Step: ', 211, 'A is: ', array([ 1.02253711], dtype=float32), ' b is: ', array([-0.63129824], dtype=float32))
# ('Loss: ', array([ 0.00015408], dtype=float32))
# ('Step: ', 212, 'A is: ', array([ 1.02262688], dtype=float32), ' b is: ', array([-0.63129497], dtype=float32))
# ('Loss: ', array([ 0.00019627], dtype=float32))
# ('Step: ', 213, 'A is: ', array([ 1.02268434], dtype=float32), ' b is: ', array([-0.63129288], dtype=float32))
# ('Loss: ', array([  7.91365746e-05], dtype=float32))
# ('Step: ', 214, 'A is: ', array([ 1.02272546], dtype=float32), ' b is: ', array([-0.63129139], dtype=float32))
# ('Loss: ', array([  4.01959405e-05], dtype=float32))
# ('Step: ', 215, 'A is: ', array([ 1.02267325], dtype=float32), ' b is: ', array([-0.63129324], dtype=float32))
# ('Loss: ', array([  6.08267183e-05], dtype=float32))
# ('Step: ', 216, 'A is: ', array([ 1.02275968], dtype=float32), ' b is: ', array([-0.63129008], dtype=float32))
# ('Loss: ', array([ 0.00018448], dtype=float32))
# ('Step: ', 217, 'A is: ', array([ 1.02265239], dtype=float32), ' b is: ', array([-0.63129383], dtype=float32))
# ('Loss: ', array([ 0.00024677], dtype=float32))
# ('Step: ', 218, 'A is: ', array([ 1.02252293], dtype=float32), ' b is: ', array([-0.6312983], dtype=float32))
# ('Loss: ', array([ 0.00034953], dtype=float32))
# ('Step: ', 219, 'A is: ', array([ 1.02261853], dtype=float32), ' b is: ', array([-0.63129479], dtype=float32))
# ('Loss: ', array([ 0.00022315], dtype=float32))
# ('Step: ', 220, 'A is: ', array([ 1.02269626], dtype=float32), ' b is: ', array([-0.63129193], dtype=float32))
# ('Loss: ', array([ 0.00014678], dtype=float32))
# ('Step: ', 221, 'A is: ', array([ 1.02268076], dtype=float32), ' b is: ', array([-0.63129246], dtype=float32))
# ('Loss: ', array([  5.47708260e-06], dtype=float32))
# ('Step: ', 222, 'A is: ', array([ 1.02267361], dtype=float32), ' b is: ', array([-0.6312927], dtype=float32))
# ('Loss: ', array([  1.17783566e-06], dtype=float32))
# ('Step: ', 223, 'A is: ', array([ 1.02274501], dtype=float32), ' b is: ', array([-0.63129008], dtype=float32))
# ('Loss: ', array([ 0.00012416], dtype=float32))
# ('Step: ', 224, 'A is: ', array([ 1.02282655], dtype=float32), ' b is: ', array([-0.6312871], dtype=float32))
# ('Loss: ', array([ 0.00016473], dtype=float32))
# ('Step: ', 225, 'A is: ', array([ 1.02284026], dtype=float32), ' b is: ', array([-0.63128662], dtype=float32))
# ('Loss: ', array([  4.48235369e-06], dtype=float32))
# ('Step: ', 226, 'A is: ', array([ 1.02285194], dtype=float32), ' b is: ', array([-0.6312862], dtype=float32))
# ('Loss: ', array([  3.22136111e-06], dtype=float32))
# ('Step: ', 227, 'A is: ', array([ 1.02287555], dtype=float32), ' b is: ', array([-0.63128537], dtype=float32))
# ('Loss: ', array([  1.33134345e-05], dtype=float32))
# ('Step: ', 228, 'A is: ', array([ 1.02290916], dtype=float32), ' b is: ', array([-0.63128412], dtype=float32))
# ('Loss: ', array([  2.72726320e-05], dtype=float32))
# ('Step: ', 229, 'A is: ', array([ 1.02294731], dtype=float32), ' b is: ', array([-0.63128269], dtype=float32))
# ('Loss: ', array([  3.56181445e-05], dtype=float32))
# ('Step: ', 230, 'A is: ', array([ 1.02297604], dtype=float32), ' b is: ', array([-0.63128161], dtype=float32))
# ('Loss: ', array([  1.99882779e-05], dtype=float32))
# ('Step: ', 231, 'A is: ', array([ 1.02279913], dtype=float32), ' b is: ', array([-0.63128775], dtype=float32))
# ('Loss: ', array([ 0.00065538], dtype=float32))
# ('Step: ', 232, 'A is: ', array([ 1.02285373], dtype=float32), ' b is: ', array([-0.63128573], dtype=float32))
# ('Loss: ', array([  7.26250582e-05], dtype=float32))
# ('Step: ', 233, 'A is: ', array([ 1.02289057], dtype=float32), ' b is: ', array([-0.63128436], dtype=float32))
# ('Loss: ', array([  3.28510396e-05], dtype=float32))
# ('Step: ', 234, 'A is: ', array([ 1.02283657], dtype=float32), ' b is: ', array([-0.63128626], dtype=float32))
# ('Loss: ', array([  6.62066886e-05], dtype=float32))
# ('Step: ', 235, 'A is: ', array([ 1.02290654], dtype=float32), ' b is: ', array([-0.6312837], dtype=float32))
# ('Loss: ', array([ 0.00012154], dtype=float32))
# ('Step: ', 236, 'A is: ', array([ 1.02294326], dtype=float32), ' b is: ', array([-0.63128233], dtype=float32))
# ('Loss: ', array([  3.28291790e-05], dtype=float32))
# ('Step: ', 237, 'A is: ', array([ 1.02277815], dtype=float32), ' b is: ', array([-0.63128805], dtype=float32))
# ('Loss: ', array([ 0.00057299], dtype=float32))
# ('Step: ', 238, 'A is: ', array([ 1.02269483], dtype=float32), ' b is: ', array([-0.63129097], dtype=float32))
# ('Loss: ', array([ 0.00015172], dtype=float32))
# ('Step: ', 239, 'A is: ', array([ 1.02274203], dtype=float32), ' b is: ', array([-0.63128924], dtype=float32))
# ('Loss: ', array([  5.35045729e-05], dtype=float32))
# ('Step: ', 240, 'A is: ', array([ 1.02265632], dtype=float32), ' b is: ', array([-0.63129228], dtype=float32))
# ('Loss: ', array([ 0.00015962], dtype=float32))
# ('Step: ', 241, 'A is: ', array([ 1.02257824], dtype=float32), ' b is: ', array([-0.63129503], dtype=float32))
# ('Loss: ', array([ 0.0001318], dtype=float32))
# ('Step: ', 242, 'A is: ', array([ 1.02263546], dtype=float32), ' b is: ', array([-0.63129294], dtype=float32))
# ('Loss: ', array([  7.77513487e-05], dtype=float32))
# ('Step: ', 243, 'A is: ', array([ 1.02271998], dtype=float32), ' b is: ', array([-0.63128984], dtype=float32))
# ('Loss: ', array([ 0.00017542], dtype=float32))
# ('Step: ', 244, 'A is: ', array([ 1.02266037], dtype=float32), ' b is: ', array([-0.63129193], dtype=float32))
# ('Loss: ', array([  7.84593285e-05], dtype=float32))
# ('Step: ', 245, 'A is: ', array([ 1.02273178], dtype=float32), ' b is: ', array([-0.6312893], dtype=float32))
# ('Loss: ', array([ 0.00012416], dtype=float32))
# ('Step: ', 246, 'A is: ', array([ 1.02271068], dtype=float32), ' b is: ', array([-0.63129008], dtype=float32))
# ('Loss: ', array([  1.00974139e-05], dtype=float32))
# ('Step: ', 247, 'A is: ', array([ 1.02279723], dtype=float32), ' b is: ', array([-0.63128686], dtype=float32))
# ('Loss: ', array([ 0.00018577], dtype=float32))
# ('Step: ', 248, 'A is: ', array([ 1.02272737], dtype=float32), ' b is: ', array([-0.63128936], dtype=float32))
# ('Loss: ', array([ 0.00010818], dtype=float32))
# ('Step: ', 249, 'A is: ', array([ 1.0226686], dtype=float32), ' b is: ', array([-0.63129145], dtype=float32))
# ('Loss: ', array([  7.63783610e-05], dtype=float32))
# ('Step: ', 250, 'A is: ', array([ 1.02258861], dtype=float32), ' b is: ', array([-0.63129425], dtype=float32))
# ('Loss: ', array([ 0.00013867], dtype=float32))
# ('Step: ', 251, 'A is: ', array([ 1.02255404], dtype=float32), ' b is: ', array([-0.6312955], dtype=float32))
# ('Loss: ', array([  2.64619630e-05], dtype=float32))
# ('Step: ', 252, 'A is: ', array([ 1.02249873], dtype=float32), ' b is: ', array([-0.63129747], dtype=float32))
# ('Loss: ', array([  6.64241379e-05], dtype=float32))
# ('Step: ', 253, 'A is: ', array([ 1.0226109], dtype=float32), ' b is: ', array([-0.63129336], dtype=float32))
# ('Loss: ', array([ 0.0003106], dtype=float32))
# ('Step: ', 254, 'A is: ', array([ 1.02269912], dtype=float32), ' b is: ', array([-0.63129014], dtype=float32))
# ('Loss: ', array([ 0.00019075], dtype=float32))
# ('Step: ', 255, 'A is: ', array([ 1.02261412], dtype=float32), ' b is: ', array([-0.63129312], dtype=float32))
# ('Loss: ', array([ 0.00015632], dtype=float32))
# ('Step: ', 256, 'A is: ', array([ 1.02254295], dtype=float32), ' b is: ', array([-0.63129562], dtype=float32))
# ('Loss: ', array([ 0.00010969], dtype=float32))
# ('Step: ', 257, 'A is: ', array([ 1.02243173], dtype=float32), ' b is: ', array([-0.6312995], dtype=float32))
# ('Loss: ', array([ 0.00025804], dtype=float32))
# ('Step: ', 258, 'A is: ', array([ 1.02256477], dtype=float32), ' b is: ', array([-0.63129455], dtype=float32))
# ('Loss: ', array([ 0.00044084], dtype=float32))
# ('Step: ', 259, 'A is: ', array([ 1.02246237], dtype=float32), ' b is: ', array([-0.63129812], dtype=float32))
# ('Loss: ', array([ 0.00022031], dtype=float32))
# ('Step: ', 260, 'A is: ', array([ 1.02257264], dtype=float32), ' b is: ', array([-0.63129407], dtype=float32))
# ('Loss: ', array([ 0.00029776], dtype=float32))
# ('Step: ', 261, 'A is: ', array([ 1.02252245], dtype=float32), ' b is: ', array([-0.63129586], dtype=float32))
# ('Loss: ', array([  5.51068806e-05], dtype=float32))
# ('Step: ', 262, 'A is: ', array([ 1.02258801], dtype=float32), ' b is: ', array([-0.63129348], dtype=float32))
# ('Loss: ', array([ 0.0001025], dtype=float32))
# ('Step: ', 263, 'A is: ', array([ 1.02268887], dtype=float32), ' b is: ', array([-0.63128978], dtype=float32))
# ('Loss: ', array([ 0.00025141], dtype=float32))
# ('Step: ', 264, 'A is: ', array([ 1.02265847], dtype=float32), ' b is: ', array([-0.63129085], dtype=float32))
# ('Loss: ', array([  2.07631128e-05], dtype=float32))
# ('Step: ', 265, 'A is: ', array([ 1.02273214], dtype=float32), ' b is: ', array([-0.63128817], dtype=float32))
# ('Loss: ', array([ 0.00013206], dtype=float32))
# ('Step: ', 266, 'A is: ', array([ 1.02260208], dtype=float32), ' b is: ', array([-0.6312927], dtype=float32))
# ('Loss: ', array([ 0.00035598], dtype=float32))
# ('Step: ', 267, 'A is: ', array([ 1.02270281], dtype=float32), ' b is: ', array([-0.63128901], dtype=float32))
# ('Loss: ', array([ 0.00025086], dtype=float32))
# ('Step: ', 268, 'A is: ', array([ 1.02266014], dtype=float32), ' b is: ', array([-0.6312905], dtype=float32))
# ('Loss: ', array([  4.06567742e-05], dtype=float32))
# ('Step: ', 269, 'A is: ', array([ 1.02262425], dtype=float32), ' b is: ', array([-0.63129175], dtype=float32))
# ('Loss: ', array([  2.87872135e-05], dtype=float32))
# ('Step: ', 270, 'A is: ', array([ 1.02250791], dtype=float32), ' b is: ', array([-0.6312958], dtype=float32))
# ('Loss: ', array([ 0.00028403], dtype=float32))
# ('Step: ', 271, 'A is: ', array([ 1.02257001], dtype=float32), ' b is: ', array([-0.63129354], dtype=float32))
# ('Loss: ', array([  9.15689743e-05], dtype=float32))
# ('Step: ', 272, 'A is: ', array([ 1.0226227], dtype=float32), ' b is: ', array([-0.63129163], dtype=float32))
# ('Loss: ', array([  6.58656936e-05], dtype=float32))
# ('Step: ', 273, 'A is: ', array([ 1.02258682], dtype=float32), ' b is: ', array([-0.63129288], dtype=float32))
# ('Loss: ', array([  2.87462935e-05], dtype=float32))
# ('Step: ', 274, 'A is: ', array([ 1.0225805], dtype=float32), ' b is: ', array([-0.63129312], dtype=float32))
# ('Loss: ', array([  9.24104825e-07], dtype=float32))
# ('Step: ', 275, 'A is: ', array([ 1.02266753], dtype=float32), ' b is: ', array([-0.6312899], dtype=float32))
# ('Loss: ', array([ 0.00018494], dtype=float32))
# ('Step: ', 276, 'A is: ', array([ 1.02276039], dtype=float32), ' b is: ', array([-0.63128644], dtype=float32))
# ('Loss: ', array([ 0.00021396], dtype=float32))
# ('Step: ', 277, 'A is: ', array([ 1.02263403], dtype=float32), ' b is: ', array([-0.63129085], dtype=float32))
# ('Loss: ', array([ 0.00033759], dtype=float32))
# ('Step: ', 278, 'A is: ', array([ 1.02270937], dtype=float32), ' b is: ', array([-0.63128811], dtype=float32))
# ('Loss: ', array([ 0.00013818], dtype=float32))
# ('Step: ', 279, 'A is: ', array([ 1.02274096], dtype=float32), ' b is: ', array([-0.63128698], dtype=float32))
# ('Loss: ', array([  2.35447660e-05], dtype=float32))
# ('Step: ', 280, 'A is: ', array([ 1.02280986], dtype=float32), ' b is: ', array([-0.63128442], dtype=float32))
# ('Loss: ', array([ 0.0001165], dtype=float32))
# ('Step: ', 281, 'A is: ', array([ 1.0227685], dtype=float32), ' b is: ', array([-0.63128591], dtype=float32))
# ('Loss: ', array([  3.88291992e-05], dtype=float32))
# ('Step: ', 282, 'A is: ', array([ 1.02270317], dtype=float32), ' b is: ', array([-0.63128823], dtype=float32))
# ('Loss: ', array([  9.44383792e-05], dtype=float32))
# ('Step: ', 283, 'A is: ', array([ 1.0227356], dtype=float32), ' b is: ', array([-0.63128704], dtype=float32))
# ('Loss: ', array([  2.50106823e-05], dtype=float32))
# ('Step: ', 284, 'A is: ', array([ 1.02259219], dtype=float32), ' b is: ', array([-0.63129199], dtype=float32))
# ('Loss: ', array([ 0.00042851], dtype=float32))
# ('Step: ', 285, 'A is: ', array([ 1.02264726], dtype=float32), ' b is: ', array([-0.63128996], dtype=float32))
# ('Loss: ', array([  7.21058459e-05], dtype=float32))
# ('Step: ', 286, 'A is: ', array([ 1.02273011], dtype=float32), ' b is: ', array([-0.63128692], dtype=float32))
# ('Loss: ', array([ 0.00016807], dtype=float32))
# ('Step: ', 287, 'A is: ', array([ 1.02264428], dtype=float32), ' b is: ', array([-0.63128996], dtype=float32))
# ('Loss: ', array([ 0.00015991], dtype=float32))
# ('Step: ', 288, 'A is: ', array([ 1.0225246], dtype=float32), ' b is: ', array([-0.63129413], dtype=float32))
# ('Loss: ', array([ 0.00030053], dtype=float32))
# ('Step: ', 289, 'A is: ', array([ 1.02249825], dtype=float32), ' b is: ', array([-0.63129508], dtype=float32))
# ('Loss: ', array([  1.54231420e-05], dtype=float32))
# ('Step: ', 290, 'A is: ', array([ 1.022488], dtype=float32), ' b is: ', array([-0.63129544], dtype=float32))
# ('Loss: ', array([  2.33413084e-06], dtype=float32))
# ('Step: ', 291, 'A is: ', array([ 1.02245545], dtype=float32), ' b is: ', array([-0.63129658], dtype=float32))
# ('Loss: ', array([  2.31943886e-05], dtype=float32))
# ('Step: ', 292, 'A is: ', array([ 1.02253878], dtype=float32), ' b is: ', array([-0.63129354], dtype=float32))
# ('Loss: ', array([ 0.0001662], dtype=float32))
# ('Step: ', 293, 'A is: ', array([ 1.02263772], dtype=float32), ' b is: ', array([-0.6312899], dtype=float32))
# ('Loss: ', array([ 0.00023969], dtype=float32))
# ('Step: ', 294, 'A is: ', array([ 1.02251065], dtype=float32), ' b is: ', array([-0.63129431], dtype=float32))
# ('Loss: ', array([ 0.0003366], dtype=float32))
# ('Step: ', 295, 'A is: ', array([ 1.02260435], dtype=float32), ' b is: ', array([-0.63129085], dtype=float32))
# ('Loss: ', array([ 0.0002138], dtype=float32))
# ('Step: ', 296, 'A is: ', array([ 1.02266526], dtype=float32), ' b is: ', array([-0.63128865], dtype=float32))
# ('Loss: ', array([  8.87797796e-05], dtype=float32))
# ('Step: ', 297, 'A is: ', array([ 1.02265453], dtype=float32), ' b is: ', array([-0.63128901], dtype=float32))
# ('Loss: ', array([  2.59760782e-06], dtype=float32))
# ('Step: ', 298, 'A is: ', array([ 1.02261555], dtype=float32), ' b is: ', array([-0.63129038], dtype=float32))
# ('Loss: ', array([  3.39089056e-05], dtype=float32))
# ('Step: ', 299, 'A is: ', array([ 1.02253187], dtype=float32), ' b is: ', array([-0.6312933], dtype=float32))
# ('Loss: ', array([ 0.00015046], dtype=float32))
# ...
# ('Loss: ', array([ 0.00012412], dtype=float32))
# ('Step: ', 902, 'A is: ', array([ 1.0227015], dtype=float32), ' b is: ', array([-0.63125485], dtype=float32))
# ('Loss: ', array([  1.92616462e-05], dtype=float32))
# ('Step: ', 903, 'A is: ', array([ 1.0227437], dtype=float32), ' b is: ', array([-0.6312533], dtype=float32))
# ('Loss: ', array([  4.25015023e-05], dtype=float32))
# ('Step: ', 904, 'A is: ', array([ 1.0228045], dtype=float32), ' b is: ', array([-0.6312511], dtype=float32))
# ('Loss: ', array([  8.98613507e-05], dtype=float32))
# ('Step: ', 905, 'A is: ', array([ 1.02284849], dtype=float32), ' b is: ', array([-0.63124949], dtype=float32))
# ('Loss: ', array([  4.68866347e-05], dtype=float32))
# ('Step: ', 906, 'A is: ', array([ 1.02291465], dtype=float32), ' b is: ', array([-0.63124704], dtype=float32))
# ('Loss: ', array([ 0.00010833], dtype=float32))
# ('Step: ', 907, 'A is: ', array([ 1.02282381], dtype=float32), ' b is: ', array([-0.63125026], dtype=float32))
# ('Loss: ', array([ 0.00018272], dtype=float32))
# ('Step: ', 908, 'A is: ', array([ 1.0226953], dtype=float32), ' b is: ', array([-0.63125473], dtype=float32))
# ('Loss: ', array([ 0.00035139], dtype=float32))
# ('Step: ', 909, 'A is: ', array([ 1.02264154], dtype=float32), ' b is: ', array([-0.63125664], dtype=float32))
# ('Loss: ', array([  6.41739462e-05], dtype=float32))
# ('Step: ', 910, 'A is: ', array([ 1.02253461], dtype=float32), ' b is: ', array([-0.63126034], dtype=float32))
# ('Loss: ', array([ 0.00024182], dtype=float32))
# ('Step: ', 911, 'A is: ', array([ 1.02247], dtype=float32), ' b is: ', array([-0.6312626], dtype=float32))
# ('Loss: ', array([  8.98975122e-05], dtype=float32))
# ('Step: ', 912, 'A is: ', array([ 1.02246404], dtype=float32), ' b is: ', array([-0.63126284], dtype=float32))
# ('Loss: ', array([  7.83242285e-07], dtype=float32))
# ('Step: ', 913, 'A is: ', array([ 1.0225327], dtype=float32), ' b is: ', array([-0.63126034], dtype=float32))
# ('Loss: ', array([ 0.00011157], dtype=float32))
# ('Step: ', 914, 'A is: ', array([ 1.02243137], dtype=float32), ' b is: ', array([-0.63126385], dtype=float32))
# ('Loss: ', array([ 0.00021553], dtype=float32))
# ('Step: ', 915, 'A is: ', array([ 1.02255881], dtype=float32), ' b is: ', array([-0.63125914], dtype=float32))
# ('Loss: ', array([ 0.00040254], dtype=float32))
# ('Step: ', 916, 'A is: ', array([ 1.02253485], dtype=float32), ' b is: ', array([-0.63125998], dtype=float32))
# ('Loss: ', array([  1.28170686e-05], dtype=float32))
# ('Step: ', 917, 'A is: ', array([ 1.02264702], dtype=float32), ' b is: ', array([-0.63125587], dtype=float32))
# ('Loss: ', array([ 0.00031222], dtype=float32))
# ('Step: ', 918, 'A is: ', array([ 1.02260494], dtype=float32), ' b is: ', array([-0.63125736], dtype=float32))
# ('Loss: ', array([  3.92343500e-05], dtype=float32))
# ('Step: ', 919, 'A is: ', array([ 1.02259552], dtype=float32), ' b is: ', array([-0.63125771], dtype=float32))
# ('Loss: ', array([  2.00834256e-06], dtype=float32))
# ('Step: ', 920, 'A is: ', array([ 1.02260137], dtype=float32), ' b is: ', array([-0.63125747], dtype=float32))
# ('Loss: ', array([  8.00213456e-07], dtype=float32))
# ('Step: ', 921, 'A is: ', array([ 1.02257466], dtype=float32), ' b is: ', array([-0.63125843], dtype=float32))
# ('Loss: ', array([  1.60282107e-05], dtype=float32))
# ('Step: ', 922, 'A is: ', array([ 1.02267921], dtype=float32), ' b is: ', array([-0.63125455], dtype=float32))
# ('Loss: ', array([ 0.00027019], dtype=float32))
# ('Step: ', 923, 'A is: ', array([ 1.02276647], dtype=float32), ' b is: ', array([-0.63125134], dtype=float32))
# ('Loss: ', array([ 0.00018796], dtype=float32))
# ('Step: ', 924, 'A is: ', array([ 1.02284467], dtype=float32), ' b is: ', array([-0.63124847], dtype=float32))
# ('Loss: ', array([ 0.00015144], dtype=float32))
# ('Step: ', 925, 'A is: ', array([ 1.02277327], dtype=float32), ' b is: ', array([-0.63125104], dtype=float32))
# ('Loss: ', array([ 0.00011364], dtype=float32))
# ('Step: ', 926, 'A is: ', array([ 1.02280068], dtype=float32), ' b is: ', array([-0.63125002], dtype=float32))
# ('Loss: ', array([  1.79132658e-05], dtype=float32))
# ('Step: ', 927, 'A is: ', array([ 1.02276254], dtype=float32), ' b is: ', array([-0.63125139], dtype=float32))
# ('Loss: ', array([  3.29604518e-05], dtype=float32))
# ('Step: ', 928, 'A is: ', array([ 1.0227021], dtype=float32), ' b is: ', array([-0.63125354], dtype=float32))
# ('Loss: ', array([  8.11170466e-05], dtype=float32))
# ('Step: ', 929, 'A is: ', array([ 1.02268553], dtype=float32), ' b is: ', array([-0.63125414], dtype=float32))
# ('Loss: ', array([  6.31003422e-06], dtype=float32))
# ('Step: ', 930, 'A is: ', array([ 1.02267146], dtype=float32), ' b is: ', array([-0.63125461], dtype=float32))
# ('Loss: ', array([  4.49043364e-06], dtype=float32))
# ('Step: ', 931, 'A is: ', array([ 1.02270854], dtype=float32), ' b is: ', array([-0.63125324], dtype=float32))
# ('Loss: ', array([  3.26327608e-05], dtype=float32))
# ('Step: ', 932, 'A is: ', array([ 1.0227952], dtype=float32), ' b is: ', array([-0.63125002], dtype=float32))
# ('Loss: ', array([ 0.00018629], dtype=float32))
# ('Step: ', 933, 'A is: ', array([ 1.02270067], dtype=float32), ' b is: ', array([-0.63125336], dtype=float32))
# ('Loss: ', array([ 0.00019413], dtype=float32))
# ('Step: ', 934, 'A is: ', array([ 1.02257144], dtype=float32), ' b is: ', array([-0.63125783], dtype=float32))
# ('Loss: ', array([ 0.00035046], dtype=float32))
# ('Step: ', 935, 'A is: ', array([ 1.02265787], dtype=float32), ' b is: ', array([-0.63125467], dtype=float32))
# ('Loss: ', array([ 0.00018174], dtype=float32))
# ('Step: ', 936, 'A is: ', array([ 1.02265406], dtype=float32), ' b is: ', array([-0.63125479], dtype=float32))
# ('Loss: ', array([  3.33999196e-07], dtype=float32))
# ('Step: ', 937, 'A is: ', array([ 1.02256382], dtype=float32), ' b is: ', array([-0.63125795], dtype=float32))
# ('Loss: ', array([ 0.00017466], dtype=float32))
# ('Step: ', 938, 'A is: ', array([ 1.02250671], dtype=float32), ' b is: ', array([-0.63125998], dtype=float32))
# ('Loss: ', array([  7.08159641e-05], dtype=float32))
# ('Step: ', 939, 'A is: ', array([ 1.02262306], dtype=float32), ' b is: ', array([-0.63125569], dtype=float32))
# ('Loss: ', array([ 0.00033556], dtype=float32))
# ('Step: ', 940, 'A is: ', array([ 1.02272236], dtype=float32), ' b is: ', array([-0.63125205], dtype=float32))
# ('Loss: ', array([ 0.00024408], dtype=float32))
# ('Step: ', 941, 'A is: ', array([ 1.022807], dtype=float32), ' b is: ', array([-0.63124895], dtype=float32))
# ('Loss: ', array([ 0.0001776], dtype=float32))
# ('Step: ', 942, 'A is: ', array([ 1.02287924], dtype=float32), ' b is: ', array([-0.63124627], dtype=float32))
# ('Loss: ', array([ 0.00012923], dtype=float32))
# ('Step: ', 943, 'A is: ', array([ 1.02280223], dtype=float32), ' b is: ', array([-0.63124901], dtype=float32))
# ('Loss: ', array([ 0.00013175], dtype=float32))
# ('Step: ', 944, 'A is: ', array([ 1.0228194], dtype=float32), ' b is: ', array([-0.63124841], dtype=float32))
# ('Loss: ', array([  7.03905607e-06], dtype=float32))
# ('Step: ', 945, 'A is: ', array([ 1.02273345], dtype=float32), ' b is: ', array([-0.63125145], dtype=float32))
# ('Loss: ', array([ 0.00016219], dtype=float32))
# ('Step: ', 946, 'A is: ', array([ 1.02267969], dtype=float32), ' b is: ', array([-0.63125336], dtype=float32))
# ('Loss: ', array([  6.42962405e-05], dtype=float32))
# ('Step: ', 947, 'A is: ', array([ 1.02267241], dtype=float32), ' b is: ', array([-0.6312536], dtype=float32))
# ('Loss: ', array([  1.19028846e-06], dtype=float32))
# ('Step: ', 948, 'A is: ', array([ 1.02254784], dtype=float32), ' b is: ', array([-0.63125795], dtype=float32))
# ('Loss: ', array([ 0.0003255], dtype=float32))
# ('Step: ', 949, 'A is: ', array([ 1.02244389], dtype=float32), ' b is: ', array([-0.63126159], dtype=float32))
# ('Loss: ', array([ 0.0002263], dtype=float32))
# ('Step: ', 950, 'A is: ', array([ 1.02237785], dtype=float32), ' b is: ', array([-0.63126391], dtype=float32))
# ('Loss: ', array([  9.29981470e-05], dtype=float32))
# ('Step: ', 951, 'A is: ', array([ 1.02241766], dtype=float32), ' b is: ', array([-0.63126248], dtype=float32))
# ('Loss: ', array([  3.62584578e-05], dtype=float32))
# ('Step: ', 952, 'A is: ', array([ 1.02237809], dtype=float32), ' b is: ', array([-0.63126385], dtype=float32))
# ('Loss: ', array([  3.37757556e-05], dtype=float32))
# ('Step: ', 953, 'A is: ', array([ 1.02234912], dtype=float32), ' b is: ', array([-0.63126487], dtype=float32))
# ('Loss: ', array([  1.82865333e-05], dtype=float32))
# ('Step: ', 954, 'A is: ', array([ 1.02238178], dtype=float32), ' b is: ', array([-0.63126367], dtype=float32))
# ('Loss: ', array([  2.42721908e-05], dtype=float32))
# ('Step: ', 955, 'A is: ', array([ 1.0223918], dtype=float32), ' b is: ', array([-0.63126332], dtype=float32))
# ('Loss: ', array([  2.23610550e-06], dtype=float32))
# ('Step: ', 956, 'A is: ', array([ 1.02250302], dtype=float32), ' b is: ', array([-0.63125926], dtype=float32))
# ('Loss: ', array([ 0.00030119], dtype=float32))
# ('Step: ', 957, 'A is: ', array([ 1.02240658], dtype=float32), ' b is: ', array([-0.6312626], dtype=float32))
# ('Loss: ', array([ 0.00019514], dtype=float32))
# ('Step: ', 958, 'A is: ', array([ 1.02243614], dtype=float32), ' b is: ', array([-0.63126153], dtype=float32))
# ('Loss: ', array([  1.99201168e-05], dtype=float32))
# ('Step: ', 959, 'A is: ', array([ 1.02243161], dtype=float32), ' b is: ', array([-0.63126171], dtype=float32))
# ('Loss: ', array([  4.48202627e-07], dtype=float32))
# ('Step: ', 960, 'A is: ', array([ 1.0224278], dtype=float32), ' b is: ', array([-0.63126183], dtype=float32))
# ('Loss: ', array([  3.16595106e-07], dtype=float32))
# ('Step: ', 961, 'A is: ', array([ 1.02242267], dtype=float32), ' b is: ', array([-0.631262], dtype=float32))
# ('Loss: ', array([  5.87911927e-07], dtype=float32))
# ('Step: ', 962, 'A is: ', array([ 1.02254772], dtype=float32), ' b is: ', array([-0.63125741], dtype=float32))
# ('Loss: ', array([ 0.00038618], dtype=float32))
# ('Step: ', 963, 'A is: ', array([ 1.02260363], dtype=float32), ' b is: ', array([-0.63125539], dtype=float32))
# ('Loss: ', array([  7.40624964e-05], dtype=float32))
# ('Step: ', 964, 'A is: ', array([ 1.02257645], dtype=float32), ' b is: ', array([-0.63125634], dtype=float32))
# ('Loss: ', array([  1.64586854e-05], dtype=float32))
# ('Step: ', 965, 'A is: ', array([ 1.0224719], dtype=float32), ' b is: ', array([-0.63125998], dtype=float32))
# ('Loss: ', array([ 0.0002297], dtype=float32))
# ('Step: ', 966, 'A is: ', array([ 1.0225749], dtype=float32), ' b is: ', array([-0.63125622], dtype=float32))
# ('Loss: ', array([ 0.0002589], dtype=float32))
# ('Step: ', 967, 'A is: ', array([ 1.02262664], dtype=float32), ' b is: ', array([-0.63125432], dtype=float32))
# ('Loss: ', array([  6.35034085e-05], dtype=float32))
# ('Step: ', 968, 'A is: ', array([ 1.02272344], dtype=float32), ' b is: ', array([-0.63125074], dtype=float32))
# ('Loss: ', array([ 0.00023213], dtype=float32))
# ('Step: ', 969, 'A is: ', array([ 1.02263844], dtype=float32), ' b is: ', array([-0.63125372], dtype=float32))
# ('Loss: ', array([ 0.00015665], dtype=float32))
# ('Step: ', 970, 'A is: ', array([ 1.0225507], dtype=float32), ' b is: ', array([-0.63125682], dtype=float32))
# ('Loss: ', array([ 0.00016492], dtype=float32))
# ('Step: ', 971, 'A is: ', array([ 1.02251995], dtype=float32), ' b is: ', array([-0.63125789], dtype=float32))
# ('Loss: ', array([  2.09372993e-05], dtype=float32))
# ('Step: ', 972, 'A is: ', array([ 1.02242482], dtype=float32), ' b is: ', array([-0.63126117], dtype=float32))
# ('Loss: ', array([ 0.00019043], dtype=float32))
# ('Step: ', 973, 'A is: ', array([ 1.02233303], dtype=float32), ' b is: ', array([-0.63126433], dtype=float32))
# ('Loss: ', array([ 0.00017557], dtype=float32))
# ('Step: ', 974, 'A is: ', array([ 1.02247488], dtype=float32), ' b is: ', array([-0.63125908], dtype=float32))
# ('Loss: ', array([ 0.00049894], dtype=float32))
# ('Step: ', 975, 'A is: ', array([ 1.0224582], dtype=float32), ' b is: ', array([-0.63125968], dtype=float32))
# ('Loss: ', array([  6.12928125e-06], dtype=float32))
# ('Step: ', 976, 'A is: ', array([ 1.02256322], dtype=float32), ' b is: ', array([-0.63125581], dtype=float32))
# ('Loss: ', array([ 0.00026925], dtype=float32))
# ('Step: ', 977, 'A is: ', array([ 1.02248776], dtype=float32), ' b is: ', array([-0.63125843], dtype=float32))
# ('Loss: ', array([ 0.00012196], dtype=float32))
# ('Step: ', 978, 'A is: ', array([ 1.02244294], dtype=float32), ' b is: ', array([-0.63125998], dtype=float32))
# ('Loss: ', array([  4.35776055e-05], dtype=float32))
# ('Step: ', 979, 'A is: ', array([ 1.0225687], dtype=float32), ' b is: ', array([-0.63125533], dtype=float32))
# ('Loss: ', array([ 0.00039167], dtype=float32))
# ('Step: ', 980, 'A is: ', array([ 1.02262712], dtype=float32), ' b is: ', array([-0.63125318], dtype=float32))
# ('Loss: ', array([  8.11170466e-05], dtype=float32))
# ('Step: ', 981, 'A is: ', array([ 1.02272022], dtype=float32), ' b is: ', array([-0.63124973], dtype=float32))
# ('Loss: ', array([ 0.00021352], dtype=float32))
# ('Step: ', 982, 'A is: ', array([ 1.02280331], dtype=float32), ' b is: ', array([-0.63124669], dtype=float32))
# ('Loss: ', array([ 0.00017085], dtype=float32))
# ('Step: ', 983, 'A is: ', array([ 1.02283394], dtype=float32), ' b is: ', array([-0.63124555], dtype=float32))
# ('Loss: ', array([  2.25015137e-05], dtype=float32))
# ('Step: ', 984, 'A is: ', array([ 1.02276421], dtype=float32), ' b is: ', array([-0.63124806], dtype=float32))
# ('Loss: ', array([ 0.0001083], dtype=float32))
# ('Step: ', 985, 'A is: ', array([ 1.02269733], dtype=float32), ' b is: ', array([-0.63125044], dtype=float32))
# ('Loss: ', array([  9.88634129e-05], dtype=float32))
# ('Step: ', 986, 'A is: ', array([ 1.02256858], dtype=float32), ' b is: ', array([-0.63125491], dtype=float32))
# ('Loss: ', array([ 0.00034754], dtype=float32))
# ('Step: ', 987, 'A is: ', array([ 1.02246118], dtype=float32), ' b is: ', array([-0.63125867], dtype=float32))
# ('Loss: ', array([ 0.00024164], dtype=float32))
# ('Step: ', 988, 'A is: ', array([ 1.02246261], dtype=float32), ' b is: ', array([-0.63125861], dtype=float32))
# ('Loss: ', array([  4.16512194e-08], dtype=float32))
# ('Step: ', 989, 'A is: ', array([ 1.02255774], dtype=float32), ' b is: ', array([-0.63125515], dtype=float32))
# ('Loss: ', array([ 0.00021896], dtype=float32))
# ('Step: ', 990, 'A is: ', array([ 1.0225637], dtype=float32), ' b is: ', array([-0.63125491], dtype=float32))
# ('Loss: ', array([  7.96804670e-07], dtype=float32))
# ('Step: ', 991, 'A is: ', array([ 1.0226661], dtype=float32), ' b is: ', array([-0.63125116], dtype=float32))
# ('Loss: ', array([ 0.00025859], dtype=float32))
# ('Step: ', 992, 'A is: ', array([ 1.02254677], dtype=float32), ' b is: ', array([-0.63125533], dtype=float32))
# ('Loss: ', array([ 0.00029974], dtype=float32))
# ('Step: ', 993, 'A is: ', array([ 1.02251863], dtype=float32), ' b is: ', array([-0.63125634], dtype=float32))
# ('Loss: ', array([  1.75278728e-05], dtype=float32))
# ('Step: ', 994, 'A is: ', array([ 1.02246881], dtype=float32), ' b is: ', array([-0.63125807], dtype=float32))
# ('Loss: ', array([  5.38679305e-05], dtype=float32))
# ('Step: ', 995, 'A is: ', array([ 1.02246892], dtype=float32), ' b is: ', array([-0.63125807], dtype=float32))
# ('Loss: ', array([  7.13043846e-10], dtype=float32))
# ('Step: ', 996, 'A is: ', array([ 1.0225631], dtype=float32), ' b is: ', array([-0.63125461], dtype=float32))
# ('Loss: ', array([ 0.00021463], dtype=float32))
# ('Step: ', 997, 'A is: ', array([ 1.02256823], dtype=float32), ' b is: ', array([-0.63125443], dtype=float32))
# ('Loss: ', array([  5.84990630e-07], dtype=float32))
# ('Step: ', 998, 'A is: ', array([ 1.02267182], dtype=float32), ' b is: ', array([-0.63125062], dtype=float32))
# ('Loss: ', array([ 0.00026495], dtype=float32))
# ('Step: ', 999, 'A is: ', array([ 1.02276385], dtype=float32), ' b is: ', array([-0.63124722], dtype=float32))
# ('Loss: ', array([ 0.00021007], dtype=float32))
# ('Step: ', 1000, 'A is: ', array([ 1.02281392], dtype=float32), ' b is: ', array([-0.63124537], dtype=float32))
# ('Loss: ', array([  6.06186368e-05], dtype=float32))

# %%
# Standard Deviation
print df.std()
# Out:
# power    863.299935
# temp       2.929614
# dtype: float64

# %%
df.shape[0]
# Out:
# 5760

# %% [markdown]
# # !! Not sure how are we getting these numbers - manually?

# %%
besta = 47.33220673 
bestb = 2.49423003

# %%
# here we have calculated the best possible A and b 
# Hence we will predict the power based on these values now, 
# formula is Power = A* Temp + b

# %% [markdown]
# # SARIMA MODEL

# %%
# Split the data
X_train = df.ix[findx:mindx, "power"]
X_test = df.ix[mindx:, "power"]

# %%
# Train the model
mod = sm.tsa.statespace.SARIMAX(X_train, order=(3, 1, 2), seasonal_order=(1, 1, 1, 96))#,
#                                enforce_stationarity=False,
#                                enforce_invertibility=False)

results = mod.fit()
# Out:
# /Library/Python/2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                              power   No. Observations:                  538
# Model:             SARIMAX(3, 1, 2)x(1, 1, 1, 96)   Log Likelihood               -3163.293
# Date:                            Mon, 14 Aug 2017   AIC                           6342.586
# Time:                                    00:11:10   BIC                           6376.889
# Sample:                                07-01-2016   HQIC                          6356.004
#                                      - 07-07-2016
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0928      0.682     -0.136      0.892      -1.429       1.244
# ar.L2          0.0999      0.185      0.541      0.589      -0.262       0.462
# ar.L3          0.0989      0.069      1.442      0.149      -0.036       0.233
# ma.L1         -0.6586      0.685     -0.962      0.336      -2.001       0.683
# ma.L2         -0.3349      0.678     -0.494      0.621      -1.664       0.994
# ar.S.L96      -0.0628      0.159     -0.396      0.692      -0.374       0.249
# ma.S.L96      -0.5383      0.196     -2.753      0.006      -0.922      -0.155
# sigma2      1.334e+05   1.28e+04     10.449      0.000    1.08e+05    1.58e+05
# ===================================================================================
# Ljung-Box (Q):                       20.20   Jarque-Bera (JB):                24.41
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.83   Skew:                             0.28
# Prob(H) (two-sided):                  0.25   Kurtosis:                         4.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# # Predict Power and Anomaly

# %%
start = X_test.index[0]
end = X_test.index[-1]

print start, end
# Out:
# 2016-07-07 08:45:00 2016-07-09 18:15:00

# %%
df_pred = pd.DataFrame(results.predict(start, end))
df_pred.columns = ["pred"]

df_pred["actual"] = X_test
df_pred.head()
# Out:
#                             pred       actual
# 2016-07-07 08:45:00  1205.832872  1503.500000
# 2016-07-07 09:00:00  1310.879791  1070.933333
# 2016-07-07 09:15:00  1377.676578  1378.866667
# 2016-07-07 09:30:00  1271.465043  1154.433333
# 2016-07-07 09:45:00  1131.932713  1229.433333

# %%
fig, ax = plt.subplots()
df_pred.plot(ax=ax)

# %%
df_pred["epsilon"] = (df_pred["actual"] - df_pred["pred"]) / df_pred["pred"]
df_pred["anomaly"] = 0

# %%
df_pred.head()
# Out:
#                             pred       actual   epsilon  anomaly
# 2016-07-07 08:45:00  1205.832872  1503.500000  0.246856        0
# 2016-07-07 09:00:00  1310.879791  1070.933333 -0.183042        0
# 2016-07-07 09:15:00  1377.676578  1378.866667  0.000864        0
# 2016-07-07 09:30:00  1271.465043  1154.433333 -0.092045        0
# 2016-07-07 09:45:00  1131.932713  1229.433333  0.086136        0

# %%
# H and L for anomaly detection
alpha = 0.998

H = df_pred.epsilon.quantile(alpha)
L = df_pred.epsilon.quantile(1.0 - alpha)

# %%
print H, L
# Out:
# 0.587327999487 -0.371429022805

# %%
df_pred.loc[df_pred.epsilon > H, "anomaly"] = 1
df_pred.loc[df_pred.epsilon < L, "anomaly"] = -1

# %%
df_pred[df_pred.epsilon < L]
# Out:
#                             pred  actual   epsilon  anomaly
# 2016-07-09 12:45:00  1882.237644  1178.8 -0.373724       -1

# %%
df_pred[df_pred.epsilon > H]
# Out:
#                             pred       actual   epsilon  anomaly
# 2016-07-08 05:15:00  1619.543819  2593.533333  0.601397        1

# %% [markdown]
# # Unused Code

# %%
#def anomalydetect(df):  
#    
#    v_pred = df.ix[0]
#    v_act = df.ix[1]
#    
#    epsilon = (v_act - v_pred) / v_pred 
#    
    # Positive Outlier
#    if epsilon > H :
#        return 1
    # Negative Outlier
#    elif epsilon < L:
#        return -1
    # Normal
#    else:
#        return 0

# %%
#df_pred.apply(anomalydetect, axis=1)

# %%
#new_predicted

# %%
#plt.plot(new_predicted, color = "red")
#plt.plot(predicted, color= "green")
#plt.plot(test)
#plt.show()

# %%
#simple 2 min resampling
#def returnsample(power):
#    returnempty = []
#    for i in range(0,round(power.shape[0]/120)-1):
#        empty = []
#        empty = power[i*120+1:i*120+120]
#        returnempty.append(np.average(empty))
#        
#    empty = power[120*(round(power.shape[0]/120)-1):]
#    returnempty.append(np.average(empty))
#    
#    return returnempty

# %%
#power_data = returnsample(power["Power"].values)
#temp_data = returnsample(temp["Temp"].values)

# %%
#power_data = np.array(power_data)
#power_data = power_data.astype(int)
#
#temp_data = np.array(temp_data)
#temp_data = temp_data.astype(int)

# %%
#print(len(power_data))
#len(temp_data)
