# %%
import numpy as np
import pandas as pd
import warnings

import matplotlib
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.patches as patches

warnings.filterwarnings('ignore')

# %%
#mapping = pd.read_csv("Mapping_csv.csv")
mapping = pd.read_csv("../../../data/essentials/md_paths_v3.csv", index_col=[0])

#reports = pd.read_csv("AnomalyReportData.csv")
reports = pd.read_excel('../../../data/essentials/Report By Category.xls', index_col=[0])

# %%
# Only Select Milk Chilling Units
reports = reports[(reports["Equipment Type"] == "MILK CHIILLING UNIT") | \
                  (reports["Equipment Type"] == "MILK CHILLING UNIT")]

reports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4917 entries, 287523 to 417820
# Data columns (total 82 columns):
# Request Status                               4917 non-null object
# Created Date                                 4917 non-null datetime64[ns]
# SLA Crossed                                  4917 non-null object
# Priority                                     4917 non-null object
# Request Type                                 4917 non-null object
# Equipment Type                               4917 non-null object
# Equipment Sap Code                           4917 non-null object
# Equipment   Serial No                        4917 non-null object
# Equipment Description                        4917 non-null object
# Category                                     4917 non-null object
# SubCategory                                  4917 non-null object
# Major Issue                                  4917 non-null object
# Description                                  4888 non-null object
# SKU                                          0 non-null float64
# Product Batch Code                           0 non-null float64
# Processing Plant                             0 non-null float64
# Manufacturing / Production / Used By Date    0 non-null float64
# Escalation Level                             4917 non-null object
# Assigned - Internal Entity                   2 non-null object
# Escalation - Internal Entity                 2635 non-null object
# Assigned - External Entity                   4917 non-null object
# Escalation - External Entity                 0 non-null object
# Sub Assigned                                 98 non-null object
# Ticket Number                                0 non-null object
# Closure Comments By End User                 1 non-null object
# End User Confirmation                        1 non-null object
# End User Confirmation Datetime               1 non-null object
# Assigned Date                                4917 non-null datetime64[ns]
# Sub Assigned Date                            98 non-null object
# Escaltion Date                               2635 non-null datetime64[ns]
# Due Date                                     4917 non-null datetime64[ns]
# Complete Date                                4911 non-null datetime64[ns]
# Close Date                                   4910 non-null datetime64[ns]
# Requester Type                               4917 non-null object
# Requester Name                               4917 non-null object
# Requester Registered Phone No                4917 non-null object
# Requester Calling No                         4917 non-null object
# Requester Alternate Phone No                 3942 non-null object
# Requester Email ID                           83 non-null object
# Requester State                              0 non-null object
# Requester District                           0 non-null object
# Requester City                               0 non-null object
# Requester Location                           0 non-null object
# Requester SAP Code                           2306 non-null object
# Email ID to Notify                           0 non-null float64
# Service State                                4917 non-null object
# Service District                             4917 non-null object
# Service City                                 4917 non-null object
# Service Location SAP                         4917 non-null object
# Service Location                             4917 non-null int64
# Service Location Type                        4917 non-null object
# Service Location Phone                       4917 non-null int64
# Service Location Address                     4917 non-null object
# Repeated in last 48 hours                    4917 non-null object
# Resolution Code                              4534 non-null object
# Replacement Item                             0 non-null object
# Replacement Quantity                         0 non-null float64
# Resolution Description                       4468 non-null object
# Actual Close Datetime                        1243 non-null datetime64[ns]
# Hold Date                                    0 non-null object
# Total Hold Time (In Minutes)                 4917 non-null int64
# Reopen Count                                 267 non-null float64
# Request Lodged By                            4688 non-null object
# Request Mode                                 4917 non-null object
# Service Process                              4917 non-null object
# Customer Satisfaction                        0 non-null float64
# Escalation Level 1                           0 non-null float64
# Escalation Level 1 SAP                       0 non-null float64
# Escalation Level 2                           0 non-null float64
# Escalation Level 2 SAP                       0 non-null float64
# Escalation Level 3                           0 non-null float64
# Escalation Level 3 SAP                       0 non-null float64
# Escalation Level 4                           0 non-null float64
# Escalation Level 4 SAP                       0 non-null float64
# Escalation Level 5                           0 non-null float64
# Escalation Level 5 SAP                       0 non-null float64
# Escalation Level PQ 1                        0 non-null float64
# Escalation Level PQ 1 SAP                    0 non-null float64
# Escalation Level PQ 2                        0 non-null float64
# Escalation Level PQ 2 SAP                    0 non-null float64
# Escalation Level PQ 3                        0 non-null float64
# Escalation Level PQ 3 SAP                    0 non-null float64
# dtypes: datetime64[ns](7), float64(24), int64(3), object(48)
# memory usage: 3.1+ MB

# %%
# Fetch Booth Number and Client Display Number
mapping = mapping[~mapping["client_display_name"].isnull()]

mapping["booth_id"] = list(mapping['client_display_name'].apply(lambda x: x.split("|")[0].split(".")[-1]).astype(int))
mapping["num"] = list(mapping['MD_id'].apply(lambda x: abs(int(x.split("MotherDairy")[1]))))

mapping.head()
# Out:
#              MD_id             client_display_name  \
# 0   MotherDairy-89  Booth No. 601 | Rajouri Garden
# 1   MotherDairy-59    Booth No. 3 | Kailash Colony
# 2   MotherDairy-93          Booth No. 538 | Rohini
# 3  MotherDairy-119       Booth No. 656 | Pitampura
# 4   MotherDairy-33         Booth No. 922 | Gurgaon
#
#                               path_mcu  \
# 0   /MotherDairy-89/Meter2/PowerBPhase
# 1   /MotherDairy-59/Meter2/PowerBPhase
# 2   /MotherDairy-93/Meter2/PowerBPhase
# 3  /MotherDairy-119/Meter2/PowerBPhase
# 4   /MotherDairy-33/Meter2/PowerBPhase
#
#                                            path_temp  \
# 0     /MotherDairy-89/TemperatureSensor4/Temperature
# 1     /MotherDairy-59/TemperatureSensor4/Temperature
# 2     /MotherDairy-93/TemperatureSensor4/Temperature
# 3  /MotherDairy-119/TemperatureSensor100/Temperature
# 4     /MotherDairy-33/TemperatureSensor4/Temperature
#
#                                path_relay  \
# 0   /MotherDairy-89/Relay11/RemoteControl
# 1   /MotherDairy-59/Relay10/RemoteControl
# 2   /MotherDairy-93/Relay10/RemoteControl
# 3  /MotherDairy-119/Relay11/RemoteControl
# 4   /MotherDairy-33/Relay10/RemoteControl
#
#                               path_door  \
# 0   /MotherDairy-89/ReedSensor15/Status
# 1   /MotherDairy-59/ReedSensor15/Status
# 2   /MotherDairy-93/ReedSensor15/Status
# 3  /MotherDairy-119/ReedSensor50/Status
# 4   /MotherDairy-33/ReedSensor15/Status
#
#                                          path_amb  booth_id  num
# 0  /MotherDairy-89/TemperatureSensor6/Temperature       601   89
# 1  /MotherDairy-59/TemperatureSensor6/Temperature         3   59
# 2  /MotherDairy-93/TemperatureSensor6/Temperature       538   93
# 3                                             NaN       656  119
# 4  /MotherDairy-33/TemperatureSensor5/Temperature       922   33

# %%
# Read Power and Temperature Data
st_streams = pd.HDFStore('../../../data/raw/streams.h5')

power = st_streams['/streams/mcu']
temp = st_streams['/streams/temp']

st_streams.close()

# %%
# Booths for which we have data
mds = [int(k.split('mdb')[1]) for k in power.columns.values]
booths = list(mapping[mapping["num"].isin(mds)]["booth_id"])

# %%
# Only select booths for which we have data
reports = reports[(reports[u'Service Location'].isin(booths)) & \
                  (reports[u'Request Status'] == 'Closed')]

reports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 723 entries, 287537 to 415951
# Data columns (total 82 columns):
# Request Status                               723 non-null object
# Created Date                                 723 non-null datetime64[ns]
# SLA Crossed                                  723 non-null object
# Priority                                     723 non-null object
# Request Type                                 723 non-null object
# Equipment Type                               723 non-null object
# Equipment Sap Code                           723 non-null object
# Equipment   Serial No                        723 non-null object
# Equipment Description                        723 non-null object
# Category                                     723 non-null object
# SubCategory                                  723 non-null object
# Major Issue                                  723 non-null object
# Description                                  716 non-null object
# SKU                                          0 non-null float64
# Product Batch Code                           0 non-null float64
# Processing Plant                             0 non-null float64
# Manufacturing / Production / Used By Date    0 non-null float64
# Escalation Level                             723 non-null object
# Assigned - Internal Entity                   0 non-null object
# Escalation - Internal Entity                 376 non-null object
# Assigned - External Entity                   723 non-null object
# Escalation - External Entity                 0 non-null object
# Sub Assigned                                 20 non-null object
# Ticket Number                                0 non-null object
# Closure Comments By End User                 0 non-null object
# End User Confirmation                        0 non-null object
# End User Confirmation Datetime               0 non-null object
# Assigned Date                                723 non-null datetime64[ns]
# Sub Assigned Date                            20 non-null object
# Escaltion Date                               376 non-null datetime64[ns]
# Due Date                                     723 non-null datetime64[ns]
# Complete Date                                723 non-null datetime64[ns]
# Close Date                                   723 non-null datetime64[ns]
# Requester Type                               723 non-null object
# Requester Name                               723 non-null object
# Requester Registered Phone No                723 non-null object
# Requester Calling No                         723 non-null object
# Requester Alternate Phone No                 583 non-null object
# Requester Email ID                           11 non-null object
# Requester State                              0 non-null object
# Requester District                           0 non-null object
# Requester City                               0 non-null object
# Requester Location                           0 non-null object
# Requester SAP Code                           333 non-null object
# Email ID to Notify                           0 non-null float64
# Service State                                723 non-null object
# Service District                             723 non-null object
# Service City                                 723 non-null object
# Service Location SAP                         723 non-null object
# Service Location                             723 non-null int64
# Service Location Type                        723 non-null object
# Service Location Phone                       723 non-null int64
# Service Location Address                     723 non-null object
# Repeated in last 48 hours                    723 non-null object
# Resolution Code                              670 non-null object
# Replacement Item                             0 non-null object
# Replacement Quantity                         0 non-null float64
# Resolution Description                       656 non-null object
# Actual Close Datetime                        187 non-null datetime64[ns]
# Hold Date                                    0 non-null object
# Total Hold Time (In Minutes)                 723 non-null int64
# Reopen Count                                 42 non-null float64
# Request Lodged By                            691 non-null object
# Request Mode                                 723 non-null object
# Service Process                              723 non-null object
# Customer Satisfaction                        0 non-null float64
# Escalation Level 1                           0 non-null float64
# Escalation Level 1 SAP                       0 non-null float64
# Escalation Level 2                           0 non-null float64
# Escalation Level 2 SAP                       0 non-null float64
# Escalation Level 3                           0 non-null float64
# Escalation Level 3 SAP                       0 non-null float64
# Escalation Level 4                           0 non-null float64
# Escalation Level 4 SAP                       0 non-null float64
# Escalation Level 5                           0 non-null float64
# Escalation Level 5 SAP                       0 non-null float64
# Escalation Level PQ 1                        0 non-null float64
# Escalation Level PQ 1 SAP                    0 non-null float64
# Escalation Level PQ 2                        0 non-null float64
# Escalation Level PQ 2 SAP                    0 non-null float64
# Escalation Level PQ 3                        0 non-null float64
# Escalation Level PQ 3 SAP                    0 non-null float64
# dtypes: datetime64[ns](7), float64(24), int64(3), object(48)
# memory usage: 468.8+ KB

# %%
# Select only required columns
reports_sub = reports[["Service Location" , "Created Date", "Close Date", \
                       "Major Issue", "Description", "Resolution Description"]].reset_index()
reports_sub.head()
# Out:
#    Request No  Service Location            Created Date  \
# 0      287537               744 2016-04-01 08:09:14.463
# 1      287912                99 2016-04-01 17:15:29.810
# 2      288009               956 2016-04-02 08:03:46.887
# 3      288133               853 2016-04-02 10:49:50.677
# 4      288445               423 2016-04-02 18:01:53.000
#
#                Close Date    Major Issue  \
# 0 2016-04-02 14:42:13.420  MCU temp high
# 1 2016-04-03 06:49:01.713  MCU temp high
# 2 2016-04-03 06:48:51.507  MCU temp high
# 3 2016-04-03 15:25:20.007  MCU temp high
# 4 2016-04-03 06:47:20.933  MCU temp high
#
#                                          Description  \
# 0  Shopkeeper complaint that his MCU is not cooli...
# 1  Shopkeeper complaint that his MCU is not cooling.
# 2  Shopkeeper complaint that his MCU is not cooli...
# 3  Shopkeeper complaint that his MCU is not cooli...
# 4   \nShopkeeper complaint that his MCU is not co...
#
#                          Resolution Description
# 0     Ice malte by technician  MCU working good
# 1   Ice mallt by technician  MCU   working good
# 2  Ice  malte by  technician  MCU  working good
# 3     Starting capictor change MCU working good
# 4                         Contecat  by  harmeet

# %%
# Output Frame
df_man = reports_sub.copy()
df_man.head()
# Out:
#    Request No  Service Location            Created Date  \
# 0      287537               744 2016-04-01 08:09:14.463
# 1      287912                99 2016-04-01 17:15:29.810
# 2      288009               956 2016-04-02 08:03:46.887
# 3      288133               853 2016-04-02 10:49:50.677
# 4      288445               423 2016-04-02 18:01:53.000
#
#                Close Date    Major Issue  \
# 0 2016-04-02 14:42:13.420  MCU temp high
# 1 2016-04-03 06:49:01.713  MCU temp high
# 2 2016-04-03 06:48:51.507  MCU temp high
# 3 2016-04-03 15:25:20.007  MCU temp high
# 4 2016-04-03 06:47:20.933  MCU temp high
#
#                                          Description  \
# 0  Shopkeeper complaint that his MCU is not cooli...
# 1  Shopkeeper complaint that his MCU is not cooling.
# 2  Shopkeeper complaint that his MCU is not cooli...
# 3  Shopkeeper complaint that his MCU is not cooli...
# 4   \nShopkeeper complaint that his MCU is not co...
#
#                          Resolution Description
# 0     Ice malte by technician  MCU working good
# 1   Ice mallt by technician  MCU   working good
# 2  Ice  malte by  technician  MCU  working good
# 3     Starting capictor change MCU working good
# 4                         Contecat  by  harmeet

# %%
# Get MD_ID from Booth_ID
def get_num(booth_id):
    return int(mapping.ix[mapping["booth_id"] == booth_id, "num"].values[0])

# %%
plt_data = False

# Create CSV and Generate Plots
for i, r in df_man.iterrows():
    
    cr_adt = df_man.ix[i, "Created Date"]
    cl_adt = df_man.ix[i, "Close Date"]
    
    cr_dt = cr_adt - pd.to_timedelta(20, unit='d')
    cl_dt = cl_adt + pd.to_timedelta(5, unit='d')

    sindx = str(cr_dt.date())
    eindx = str(cl_dt.date())

    elapsed_time = (cl_dt.date() - cr_dt.date()).total_seconds()
    n_instances = elapsed_time / 30.0

    service_location = df_man.ix[i, "Service Location"]
    bth_id = get_num(service_location)
    bth_col = "mdb" + str(bth_id)

    # print sindx, eindx, bth_id, bth_col, elapsed_time, n_instances

    pow_sub = power.ix[sindx:eindx, bth_col]
    temp_sub = temp.ix[sindx:eindx, bth_col]

    # print pow_sub.shape

    df_man.ix[i, "start"] = cr_dt.date()
    df_man.ix[i, "stop"] = cl_dt.date()
    df_man.ix[i, "md_id"] = bth_id
    df_man.ix[i, "pow_data"] = (pow_sub.count()) / n_instances
    df_man.ix[i, "temp_data"] = (temp_sub.count()) / n_instances
    
    if (pow_sub.count() > 0) & (temp_sub.count() > 0) & (plt_data == True):
        fig, ax = plt.subplots(figsize=(16, 9))

        pow_sub.dropna().plot(ax=ax, color='blue', fontsize=20)
        ax.set_ylabel('Power (kWh)', fontsize=20, color='blue')

        ax2 = ax.twinx()
        temp_sub.dropna().plot(ax=ax2, color='red', fontsize=20)
        ax2.set_ylabel('Temperature', fontsize=20, color='red')

        ax.add_patch(
            patches.Rectangle(
                (mdates.date2num(cr_adt), 0.1),   # (x,y)
                mdates.date2num(cl_dt) - mdates.date2num(cr_adt),          # width
                3000,          # height
                facecolor="black", 
                alpha = 0.6
            )
        )

        plt.tight_layout()
        plt.savefig('../../../figures/raw/anomalies/anom' + str(i) + '_' + str(df_man.ix[i, "Request No"]) + '.pdf')

    plt.close()

df_man.head()
# Out:
#    Request No  Service Location            Created Date  \
# 0      287537               744 2016-04-01 08:09:14.463
# 1      287912                99 2016-04-01 17:15:29.810
# 2      288009               956 2016-04-02 08:03:46.887
# 3      288133               853 2016-04-02 10:49:50.677
# 4      288445               423 2016-04-02 18:01:53.000
#
#                Close Date    Major Issue  \
# 0 2016-04-02 14:42:13.420  MCU temp high
# 1 2016-04-03 06:49:01.713  MCU temp high
# 2 2016-04-03 06:48:51.507  MCU temp high
# 3 2016-04-03 15:25:20.007  MCU temp high
# 4 2016-04-03 06:47:20.933  MCU temp high
#
#                                          Description  \
# 0  Shopkeeper complaint that his MCU is not cooli...
# 1  Shopkeeper complaint that his MCU is not cooling.
# 2  Shopkeeper complaint that his MCU is not cooli...
# 3  Shopkeeper complaint that his MCU is not cooli...
# 4   \nShopkeeper complaint that his MCU is not co...
#
#                          Resolution Description       start        stop  \
# 0     Ice malte by technician  MCU working good  2016-03-12  2016-04-07
# 1   Ice mallt by technician  MCU   working good  2016-03-12  2016-04-08
# 2  Ice  malte by  technician  MCU  working good  2016-03-13  2016-04-08
# 3     Starting capictor change MCU working good  2016-03-13  2016-04-08
# 4                         Contecat  by  harmeet  2016-03-13  2016-04-08
#
#    md_id  pow_data  temp_data
# 0   66.0       0.0        0.0
# 1   36.0       0.0        0.0
# 2   45.0       0.0        0.0
# 3   41.0       0.0        0.0
# 4   94.0       0.0        0.0

# %%
df_man.to_csv('../../../data/essentials/anomalies.csv', index=False, encoding='utf-8')
