# %% [markdown]
# ## Importing everything we want

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
from scipy.stats.stats import pearsonr
import itertools

# %% [markdown]
# For ease of use and explanation i'll import the popular iris dataset to work with

# %%
iris = datasets.load_iris()

# %%
iris.keys()
# Out:
# dict_keys(['data', 'target_names', 'feature_names', 'target', 'DESCR'])

# %%
X = iris.data

# %%
Xdf = pd.DataFrame(X)

# %%
Xdf.columns = iris.feature_names

# %%
Xdf
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# 6                  4.6               3.4                1.4               0.3
# 7                  5.0               3.4                1.5               0.2
# 8                  4.4               2.9                1.4               0.2
# 9                  4.9               3.1                1.5               0.1
# 10                 5.4               3.7                1.5               0.2
# ...

# %% [markdown]
# We add the target column to see the correlation there also

# %%
Xdf['target'] = pd.Series(iris.target, index=Xdf.index)

# %%
correlations = {}
columns = Xdf.columns.tolist()

for col_a, col_b in itertools.combinations(columns, 2):
    correlations[col_a + '__' + col_b] = pearsonr(Xdf.loc[:, col_a], Xdf.loc[:, col_b])

result = pd.DataFrame.from_dict(correlations, orient='index')
result.columns = ['PCC', 'p-value']

print(result.sort_index())
# Out:
#                                            PCC       p-value
# petal length (cm)__petal width (cm)   0.962757  5.776661e-86
# petal length (cm)__target             0.949043  4.155478e-76
# petal width (cm)__target              0.956464  4.775002e-81
# sepal length (cm)__petal length (cm)  0.871754  1.038454e-47
# sepal length (cm)__petal width (cm)   0.817954  2.314849e-37
# sepal length (cm)__sepal width (cm)  -0.109369  1.827652e-01
# sepal length (cm)__target             0.782561  2.890478e-32
# sepal width (cm)__petal length (cm)  -0.420516  8.429366e-08
# sepal width (cm)__petal width (cm)   -0.356544  7.523891e-06
# sepal width (cm)__target             -0.419446  9.159985e-08
