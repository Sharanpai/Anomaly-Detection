# %%
import pandas as pd
import warnings
import numpy as np
import itertools

import statsmodels.api as sm
from statsmodels.tsa.stattools import acf  
from statsmodels.tsa.stattools import pacf
from statsmodels.tsa.seasonal import seasonal_decompose

import matplotlib
# %matplotlib inline

import matplotlib.pyplot as plt
#plt.style.use('fivethirtyeight')

import tensorflow as tf
sess = tf.Session()

# %%
# Read Power Data
power_path = "../../../data/testing/power.csv" # "power.csv"
power = pd.read_csv(power_path, index_col=[0], parse_dates=True, names=["dt", "power"])

# %%
# Read Ambient Temperature Data
temp_path = "../../../data/testing/amb_temp.csv" # "amb_temp.csv"
temp = pd.read_csv(temp_path, index_col=[0], parse_dates=True, names=["dt", "temp"])

# %%
df = pd.DataFrame()

# %%
df = power.resample('2T').mean()
df["temp"] = temp.resample('2T').mean()

# %%
# Physical Model
x_data = tf.placeholder(shape = [1],dtype = tf.float32)
y_target = tf.placeholder(shape = [1], dtype = tf.float32)

# Coefficients to Learn
A = tf.Variable(tf.random_normal(shape = [1]))
b = tf.Variable(tf.random_normal(shape = [1]))

# Output Variable and Loss Function
output = tf.add(tf.multiply(x_data,A),b)
loss = tf.square(output - y_target)

# Initialisation
init = tf.global_variables_initializer()
sess.run(init)

# Set up Optimiser
my_opt = tf.train.GradientDescentOptimizer(learning_rate = 0.0001)
train_step = my_opt.minimize(loss)

# %% [markdown]
# # !! Random part is a bit confusing??

# %%
for i in range(1000):
    index = np.random.choice(60)
    
    x = [df.ix[index, 'temp']]
    y = [df.ix[index, 'temp']]
    
    sess.run(train_step, feed_dict = {x_data : x, y_target : y})
    
    print('Step: ', i+1, "A is: ", sess.run(A), " b is: ", sess.run(b))
    print('Loss: ',sess.run(loss, feed_dict = {x_data : x, y_target : y}))
# Out:
# ('Step: ', 1, 'A is: ', array([ 0.03105606], dtype=float32), ' b is: ', array([-0.46448532], dtype=float32))
# ('Loss: ', array([ 764.81195068], dtype=float32))
# ('Step: ', 2, 'A is: ', array([ 0.17881995], dtype=float32), ' b is: ', array([-0.45908749], dtype=float32))
# ('Loss: ', array([ 526.18334961], dtype=float32))
# ('Step: ', 3, 'A is: ', array([ 0.30956733], dtype=float32), ' b is: ', array([-0.45440742], dtype=float32))
# ('Loss: ', array([ 389.78710938], dtype=float32))
# ('Step: ', 4, 'A is: ', array([ 0.41517666], dtype=float32), ' b is: ', array([-0.45054293], dtype=float32))
# ('Loss: ', array([ 270.03015137], dtype=float32))
# ('Step: ', 5, 'A is: ', array([ 0.51221961], dtype=float32), ' b is: ', array([-0.4471285], dtype=float32))
# ('Loss: ', array([ 204.79264832], dtype=float32))
# ('Step: ', 6, 'A is: ', array([ 0.58726561], dtype=float32), ' b is: ', array([-0.44437766], dtype=float32))
# ('Loss: ', array([ 136.98796082], dtype=float32))
# ('Step: ', 7, 'A is: ', array([ 0.65098369], dtype=float32), ' b is: ', array([-0.44203937], dtype=float32))
# ('Loss: ', array([ 99.05691528], dtype=float32))
# ('Step: ', 8, 'A is: ', array([ 0.70620364], dtype=float32), ' b is: ', array([-0.44003138], dtype=float32))
# ('Loss: ', array([ 72.58068848], dtype=float32))
# ('Step: ', 9, 'A is: ', array([ 0.75452244], dtype=float32), ' b is: ', array([-0.4383018], dtype=float32))
# ('Loss: ', array([ 53.23464203], dtype=float32))
# ('Step: ', 10, 'A is: ', array([ 0.79564458], dtype=float32), ' b is: ', array([-0.43683642], dtype=float32))
# ('Loss: ', array([ 38.0875206], dtype=float32))
# ('Step: ', 11, 'A is: ', array([ 0.83057958], dtype=float32), ' b is: ', array([-0.43559703], dtype=float32))
# ('Loss: ', array([ 27.15504265], dtype=float32))
# ('Step: ', 12, 'A is: ', array([ 0.85835642], dtype=float32), ' b is: ', array([-0.43458235], dtype=float32))
# ('Loss: ', array([ 18.59369087], dtype=float32))
# ('Step: ', 13, 'A is: ', array([ 0.88153177], dtype=float32), ' b is: ', array([-0.43372747], dtype=float32))
# ('Loss: ', array([ 13.28829479], dtype=float32))
# ('Step: ', 14, 'A is: ', array([ 0.90284646], dtype=float32), ' b is: ', array([-0.43297213], dtype=float32))
# ('Loss: ', array([ 10.07744694], dtype=float32))
# ('Step: ', 15, 'A is: ', array([ 0.92043084], dtype=float32), ' b is: ', array([-0.43234271], dtype=float32))
# ('Loss: ', array([ 7.0504365], dtype=float32))
# ('Step: ', 16, 'A is: ', array([ 0.93531299], dtype=float32), ' b is: ', array([-0.43181092], dtype=float32))
# ('Loss: ', array([ 5.02668619], dtype=float32))
# ('Step: ', 17, 'A is: ', array([ 0.94858032], dtype=float32), ' b is: ', array([-0.43135118], dtype=float32))
# ('Loss: ', array([ 3.66830969], dtype=float32))
# ('Step: ', 18, 'A is: ', array([ 0.95920366], dtype=float32), ' b is: ', array([-0.43097472], dtype=float32))
# ('Loss: ', array([ 2.50331163], dtype=float32))
# ('Step: ', 19, 'A is: ', array([ 0.96843451], dtype=float32), ' b is: ', array([-0.43065381], dtype=float32))
# ('Loss: ', array([ 1.79198825], dtype=float32))
# ('Step: ', 20, 'A is: ', array([ 0.97614986], dtype=float32), ' b is: ', array([-0.43038589], dtype=float32))
# ('Loss: ', array([ 1.24810362], dtype=float32))
# ('Step: ', 21, 'A is: ', array([ 0.98237711], dtype=float32), ' b is: ', array([-0.4301652], dtype=float32))
# ('Loss: ', array([ 0.86017448], dtype=float32))
# ('Step: ', 22, 'A is: ', array([ 0.98761588], dtype=float32), ' b is: ', array([-0.42997965], dtype=float32))
# ('Loss: ', array([ 0.60783291], dtype=float32))
# ('Step: ', 23, 'A is: ', array([ 0.9920184], dtype=float32), ' b is: ', array([-0.42982373], dtype=float32))
# ('Loss: ', array([ 0.42925832], dtype=float32))
# ('Step: ', 24, 'A is: ', array([ 0.99553812], dtype=float32), ' b is: ', array([-0.42969432], dtype=float32))
# ('Loss: ', array([ 0.30367944], dtype=float32))
# ('Step: ', 25, 'A is: ', array([ 0.99866951], dtype=float32), ' b is: ', array([-0.42958322], dtype=float32))
# ('Loss: ', array([ 0.21816829], dtype=float32))
# ('Step: ', 26, 'A is: ', array([ 1.00122714], dtype=float32), ' b is: ', array([-0.42949], dtype=float32))
# ('Loss: ', array([ 0.15667397], dtype=float32))
# ('Step: ', 27, 'A is: ', array([ 1.00338781], dtype=float32), ' b is: ', array([-0.42941079], dtype=float32))
# ('Loss: ', array([ 0.11356121], dtype=float32))
# ('Step: ', 28, 'A is: ', array([ 1.00522268], dtype=float32), ' b is: ', array([-0.42934334], dtype=float32))
# ('Loss: ', array([ 0.08252601], dtype=float32))
# ('Step: ', 29, 'A is: ', array([ 1.00678694], dtype=float32), ' b is: ', array([-0.42928594], dtype=float32))
# ('Loss: ', array([ 0.05970247], dtype=float32))
# ('Step: ', 30, 'A is: ', array([ 1.00812614], dtype=float32), ' b is: ', array([-0.42923802], dtype=float32))
# ('Loss: ', array([ 0.04089176], dtype=float32))
# ('Step: ', 31, 'A is: ', array([ 1.00925255], dtype=float32), ' b is: ', array([-0.4291985], dtype=float32))
# ('Loss: ', array([ 0.02734313], dtype=float32))
# ('Step: ', 32, 'A is: ', array([ 1.01021349], dtype=float32), ' b is: ', array([-0.42916358], dtype=float32))
# ('Loss: ', array([ 0.02194432], dtype=float32))
# ('Step: ', 33, 'A is: ', array([ 1.01103842], dtype=float32), ' b is: ', array([-0.42913318], dtype=float32))
# ('Loss: ', array([ 0.01678147], dtype=float32))
# ('Step: ', 34, 'A is: ', array([ 1.01173949], dtype=float32), ' b is: ', array([-0.4291074], dtype=float32))
# ('Loss: ', array([ 0.01204732], dtype=float32))
# ('Step: ', 35, 'A is: ', array([ 1.01234126], dtype=float32), ' b is: ', array([-0.4290852], dtype=float32))
# ('Loss: ', array([ 0.00897131], dtype=float32))
# ('Step: ', 36, 'A is: ', array([ 1.01279581], dtype=float32), ' b is: ', array([-0.4290691], dtype=float32))
# ('Loss: ', array([ 0.0045685], dtype=float32))
# ('Step: ', 37, 'A is: ', array([ 1.01315057], dtype=float32), ' b is: ', array([-0.42905673], dtype=float32))
# ('Loss: ', array([ 0.00266212], dtype=float32))
# ('Step: ', 38, 'A is: ', array([ 1.01353145], dtype=float32), ' b is: ', array([-0.42904279], dtype=float32))
# ('Loss: ', array([ 0.00351123], dtype=float32))
# ('Step: ', 39, 'A is: ', array([ 1.01380002], dtype=float32), ' b is: ', array([-0.42903325], dtype=float32))
# ('Loss: ', array([ 0.0016042], dtype=float32))
# ('Step: ', 40, 'A is: ', array([ 1.01403451], dtype=float32), ' b is: ', array([-0.4290249], dtype=float32))
# ('Loss: ', array([ 0.00123797], dtype=float32))
# ('Step: ', 41, 'A is: ', array([ 1.01423645], dtype=float32), ' b is: ', array([-0.42901769], dtype=float32))
# ('Loss: ', array([ 0.000924], dtype=float32))
# ('Step: ', 42, 'A is: ', array([ 1.01445818], dtype=float32), ' b is: ', array([-0.42900956], dtype=float32))
# ('Loss: ', array([ 0.00119553], dtype=float32))
# ('Step: ', 43, 'A is: ', array([ 1.01457679], dtype=float32), ' b is: ', array([-0.42900535], dtype=float32))
# ('Loss: ', array([ 0.00031222], dtype=float32))
# ('Step: ', 44, 'A is: ', array([ 1.01464283], dtype=float32), ' b is: ', array([-0.42900306], dtype=float32))
# ('Loss: ', array([  9.27040819e-05], dtype=float32))
# ('Step: ', 45, 'A is: ', array([ 1.01471579], dtype=float32), ' b is: ', array([-0.4290005], dtype=float32))
# ('Loss: ', array([ 0.00011568], dtype=float32))
# ('Step: ', 46, 'A is: ', array([ 1.01485431], dtype=float32), ' b is: ', array([-0.42899546], dtype=float32))
# ('Loss: ', array([ 0.00045953], dtype=float32))
# ('Step: ', 47, 'A is: ', array([ 1.01490593], dtype=float32), ' b is: ', array([-0.42899364], dtype=float32))
# ('Loss: ', array([  5.88204457e-05], dtype=float32))
# ('Step: ', 48, 'A is: ', array([ 1.01497614], dtype=float32), ' b is: ', array([-0.42899114], dtype=float32))
# ('Loss: ', array([ 0.00011242], dtype=float32))
# ('Step: ', 49, 'A is: ', array([ 1.01510084], dtype=float32), ' b is: ', array([-0.42898655], dtype=float32))
# ('Loss: ', array([ 0.00038476], dtype=float32))
# ('Step: ', 50, 'A is: ', array([ 1.01513541], dtype=float32), ' b is: ', array([-0.42898533], dtype=float32))
# ('Loss: ', array([  2.69746270e-05], dtype=float32))
# ('Step: ', 51, 'A is: ', array([ 1.01522934], dtype=float32), ' b is: ', array([-0.42898187], dtype=float32))
# ('Loss: ', array([ 0.00021614], dtype=float32))
# ('Step: ', 52, 'A is: ', array([ 1.01530933], dtype=float32), ' b is: ', array([-0.42897892], dtype=float32))
# ('Loss: ', array([ 0.00015679], dtype=float32))
# ('Step: ', 53, 'A is: ', array([ 1.01537108], dtype=float32), ' b is: ', array([-0.42897666], dtype=float32))
# ('Loss: ', array([  9.28878144e-05], dtype=float32))
# ('Step: ', 54, 'A is: ', array([ 1.01533175], dtype=float32), ' b is: ', array([-0.42897806], dtype=float32))
# ('Loss: ', array([  3.38644932e-05], dtype=float32))
# ('Step: ', 55, 'A is: ', array([ 1.0153774], dtype=float32), ' b is: ', array([-0.42897639], dtype=float32))
# ('Loss: ', array([  4.98847257e-05], dtype=float32))
# ('Step: ', 56, 'A is: ', array([ 1.0153631], dtype=float32), ' b is: ', array([-0.42897689], dtype=float32))
# ('Loss: ', array([  4.61250602e-06], dtype=float32))
# ('Step: ', 57, 'A is: ', array([ 1.01531947], dtype=float32), ' b is: ', array([-0.42897841], dtype=float32))
# ('Loss: ', array([  4.12671361e-05], dtype=float32))
# ('Step: ', 58, 'A is: ', array([ 1.01530886], dtype=float32), ' b is: ', array([-0.4289788], dtype=float32))
# ('Loss: ', array([  2.50620360e-06], dtype=float32))
# ('Step: ', 59, 'A is: ', array([ 1.01523912], dtype=float32), ' b is: ', array([-0.42898121], dtype=float32))
# ('Loss: ', array([ 0.00010177], dtype=float32))
# ('Step: ', 60, 'A is: ', array([ 1.01524663], dtype=float32), ' b is: ', array([-0.42898095], dtype=float32))
# ('Loss: ', array([  1.27067688e-06], dtype=float32))
# ('Step: ', 61, 'A is: ', array([ 1.01522195], dtype=float32), ' b is: ', array([-0.42898181], dtype=float32))
# ('Loss: ', array([  1.33134345e-05], dtype=float32))
# ('Step: ', 62, 'A is: ', array([ 1.01527905], dtype=float32), ' b is: ', array([-0.42897972], dtype=float32))
# ('Loss: ', array([  7.75496592e-05], dtype=float32))
# ('Step: ', 63, 'A is: ', array([ 1.01529491], dtype=float32), ' b is: ', array([-0.42897916], dtype=float32))
# ('Loss: ', array([  5.74818478e-06], dtype=float32))
# ('Step: ', 64, 'A is: ', array([ 1.01537395], dtype=float32), ' b is: ', array([-0.42897624], dtype=float32))
# ('Loss: ', array([ 0.00015479], dtype=float32))
# ('Step: ', 65, 'A is: ', array([ 1.01544511], dtype=float32), ' b is: ', array([-0.42897362], dtype=float32))
# ('Loss: ', array([ 0.00012629], dtype=float32))
# ('Step: ', 66, 'A is: ', array([ 1.01539385], dtype=float32), ' b is: ', array([-0.42897543], dtype=float32))
# ('Loss: ', array([  5.74823389e-05], dtype=float32))
# ('Step: ', 67, 'A is: ', array([ 1.01543915], dtype=float32), ' b is: ', array([-0.42897376], dtype=float32))
# ('Loss: ', array([  4.97501023e-05], dtype=float32))
# ('Step: ', 68, 'A is: ', array([ 1.01550078], dtype=float32), ' b is: ', array([-0.4289715], dtype=float32))
# ('Loss: ', array([  9.46609362e-05], dtype=float32))
# ('Step: ', 69, 'A is: ', array([ 1.01554954], dtype=float32), ' b is: ', array([-0.42896971], dtype=float32))
# ('Loss: ', array([  5.89668198e-05], dtype=float32))
# ('Step: ', 70, 'A is: ', array([ 1.01548994], dtype=float32), ' b is: ', array([-0.42897183], dtype=float32))
# ('Loss: ', array([  7.84593285e-05], dtype=float32))
# ('Step: ', 71, 'A is: ', array([ 1.015517], dtype=float32), ' b is: ', array([-0.42897084], dtype=float32))
# ('Loss: ', array([  1.76078174e-05], dtype=float32))
# ('Step: ', 72, 'A is: ', array([ 1.01555955], dtype=float32), ' b is: ', array([-0.42896926], dtype=float32))
# ('Loss: ', array([  4.45397782e-05], dtype=float32))
# ('Step: ', 73, 'A is: ', array([ 1.01550674], dtype=float32), ' b is: ', array([-0.42897114], dtype=float32))
# ('Loss: ', array([  6.20526407e-05], dtype=float32))
# ('Step: ', 74, 'A is: ', array([ 1.01545537], dtype=float32), ' b is: ', array([-0.42897296], dtype=float32))
# ('Loss: ', array([  5.83241344e-05], dtype=float32))
# ('Step: ', 75, 'A is: ', array([ 1.01548755], dtype=float32), ' b is: ', array([-0.42897177], dtype=float32))
# ('Loss: ', array([  2.50488520e-05], dtype=float32))
# ('Step: ', 76, 'A is: ', array([ 1.01553822], dtype=float32), ' b is: ', array([-0.42896989], dtype=float32))
# ('Loss: ', array([  6.37772901e-05], dtype=float32))
# ('Step: ', 77, 'A is: ', array([ 1.0154916], dtype=float32), ' b is: ', array([-0.42897156], dtype=float32))
# ('Loss: ', array([  4.85732598e-05], dtype=float32))
# ('Step: ', 78, 'A is: ', array([ 1.01546478], dtype=float32), ' b is: ', array([-0.42897251], dtype=float32))
# ('Loss: ', array([  1.63351106e-05], dtype=float32))
# ('Step: ', 79, 'A is: ', array([ 1.01538491], dtype=float32), ' b is: ', array([-0.42897531], dtype=float32))
# ('Loss: ', array([ 0.00013577], dtype=float32))
# ('Step: ', 80, 'A is: ', array([ 1.0154494], dtype=float32), ' b is: ', array([-0.42897293], dtype=float32))
# ('Loss: ', array([ 0.00010312], dtype=float32))
# ('Step: ', 81, 'A is: ', array([ 1.01535773], dtype=float32), ' b is: ', array([-0.42897612], dtype=float32))
# ('Loss: ', array([ 0.00017618], dtype=float32))
# ('Step: ', 82, 'A is: ', array([ 1.01542878], dtype=float32), ' b is: ', array([-0.4289735], dtype=float32))
# ('Loss: ', array([ 0.0001254], dtype=float32))
# ('Step: ', 83, 'A is: ', array([ 1.01546502], dtype=float32), ' b is: ', array([-0.42897218], dtype=float32))
# ('Loss: ', array([  3.15951511e-05], dtype=float32))
# ('Step: ', 84, 'A is: ', array([ 1.0154314], dtype=float32), ' b is: ', array([-0.42897338], dtype=float32))
# ('Loss: ', array([  2.53360522e-05], dtype=float32))
# ('Step: ', 85, 'A is: ', array([ 1.01546204], dtype=float32), ' b is: ', array([-0.42897227], dtype=float32))
# ('Loss: ', array([  2.24653377e-05], dtype=float32))
# ('Step: ', 86, 'A is: ', array([ 1.01540804], dtype=float32), ' b is: ', array([-0.42897418], dtype=float32))
# ('Loss: ', array([  6.37772901e-05], dtype=float32))
# ('Step: ', 87, 'A is: ', array([ 1.01536834], dtype=float32), ' b is: ', array([-0.42897558], dtype=float32))
# ('Loss: ', array([  3.47357854e-05], dtype=float32))
# ('Step: ', 88, 'A is: ', array([ 1.01533914], dtype=float32), ' b is: ', array([-0.42897663], dtype=float32))
# ('Loss: ', array([  1.89282619e-05], dtype=float32))
# ('Step: ', 89, 'A is: ', array([ 1.01531041], dtype=float32), ' b is: ', array([-0.42897764], dtype=float32))
# ('Loss: ', array([  1.80913048e-05], dtype=float32))
# ('Step: ', 90, 'A is: ', array([ 1.01523614], dtype=float32), ' b is: ', array([-0.4289802], dtype=float32))
# ('Loss: ', array([ 0.00011499], dtype=float32))
# ('Step: ', 91, 'A is: ', array([ 1.01529109], dtype=float32), ' b is: ', array([-0.4289782], dtype=float32))
# ('Loss: ', array([  7.17822841e-05], dtype=float32))
# ('Step: ', 92, 'A is: ', array([ 1.01522577], dtype=float32), ' b is: ', array([-0.42898047], dtype=float32))
# ('Loss: ', array([  8.96445126e-05], dtype=float32))
# ('Step: ', 93, 'A is: ', array([ 1.01527846], dtype=float32), ' b is: ', array([-0.42897856], dtype=float32))
# ('Loss: ', array([  6.57728524e-05], dtype=float32))
# ('Step: ', 94, 'A is: ', array([ 1.01534486], dtype=float32), ' b is: ', array([-0.42897612], dtype=float32))
# ('Loss: ', array([ 0.00010719], dtype=float32))
# ('Step: ', 95, 'A is: ', array([ 1.01541781], dtype=float32), ' b is: ', array([-0.42897344], dtype=float32))
# ('Loss: ', array([ 0.0001321], dtype=float32))
# ('Step: ', 96, 'A is: ', array([ 1.01545048], dtype=float32), ' b is: ', array([-0.42897224], dtype=float32))
# ('Loss: ', array([  2.55862833e-05], dtype=float32))
# ('Step: ', 97, 'A is: ', array([ 1.01546907], dtype=float32), ' b is: ', array([-0.42897156], dtype=float32))
# ('Loss: ', array([  8.14185478e-06], dtype=float32))
# ('Step: ', 98, 'A is: ', array([ 1.01550961], dtype=float32), ' b is: ', array([-0.42897007], dtype=float32))
# ('Loss: ', array([  4.01234174e-05], dtype=float32))
# ('Step: ', 99, 'A is: ', array([ 1.01545918], dtype=float32), ' b is: ', array([-0.42897186], dtype=float32))
# ('Loss: ', array([  5.63312824e-05], dtype=float32))
# ('Step: ', 100, 'A is: ', array([ 1.01551151], dtype=float32), ' b is: ', array([-0.42896992], dtype=float32))
# ('Loss: ', array([  6.75794581e-05], dtype=float32))
# ('Step: ', 101, 'A is: ', array([ 1.01554966], dtype=float32), ' b is: ', array([-0.42896852], dtype=float32))
# ('Loss: ', array([  3.57092686e-05], dtype=float32))
# ('Step: ', 102, 'A is: ', array([ 1.01557696], dtype=float32), ' b is: ', array([-0.42896751], dtype=float32))
# ('Loss: ', array([  1.81400137e-05], dtype=float32))
# ('Step: ', 103, 'A is: ', array([ 1.01551294], dtype=float32), ' b is: ', array([-0.42896977], dtype=float32))
# ('Loss: ', array([  9.04408662e-05], dtype=float32))
# ('Step: ', 104, 'A is: ', array([ 1.01548409], dtype=float32), ' b is: ', array([-0.42897081], dtype=float32))
# ('Loss: ', array([  1.88453705e-05], dtype=float32))
# ('Step: ', 105, 'A is: ', array([ 1.01552629], dtype=float32), ' b is: ', array([-0.42896926], dtype=float32))
# ('Loss: ', array([  4.37036069e-05], dtype=float32))
# ('Step: ', 106, 'A is: ', array([ 1.01553333], dtype=float32), ' b is: ', array([-0.428969], dtype=float32))
# ('Loss: ', array([  1.16544834e-06], dtype=float32))
# ('Step: ', 107, 'A is: ', array([ 1.01554859], dtype=float32), ' b is: ', array([-0.42896843], dtype=float32))
# ('Loss: ', array([  5.57572639e-06], dtype=float32))
# ('Step: ', 108, 'A is: ', array([ 1.01544046], dtype=float32), ' b is: ', array([-0.42897218], dtype=float32))
# ('Loss: ', array([ 0.00024521], dtype=float32))
# ('Step: ', 109, 'A is: ', array([ 1.01549423], dtype=float32), ' b is: ', array([-0.42897019], dtype=float32))
# ('Loss: ', array([  7.13949703e-05], dtype=float32))
# ('Step: ', 110, 'A is: ', array([ 1.01554275], dtype=float32), ' b is: ', array([-0.4289684], dtype=float32))
# ('Loss: ', array([  5.80622327e-05], dtype=float32))
# ('Step: ', 111, 'A is: ', array([ 1.01548707], dtype=float32), ' b is: ', array([-0.42897037], dtype=float32))
# ('Loss: ', array([  6.88080036e-05], dtype=float32))
# ('Step: ', 112, 'A is: ', array([ 1.0154444], dtype=float32), ' b is: ', array([-0.42897189], dtype=float32))
# ('Loss: ', array([  4.04381572e-05], dtype=float32))
# ('Step: ', 113, 'A is: ', array([ 1.0154345], dtype=float32), ' b is: ', array([-0.42897224], dtype=float32))
# ('Loss: ', array([  2.25898111e-06], dtype=float32))
# ('Step: ', 114, 'A is: ', array([ 1.01548016], dtype=float32), ' b is: ', array([-0.42897058], dtype=float32))
# ('Loss: ', array([  5.09138081e-05], dtype=float32))
# ('Step: ', 115, 'A is: ', array([ 1.0154134], dtype=float32), ' b is: ', array([-0.42897293], dtype=float32))
# ('Loss: ', array([  9.66007356e-05], dtype=float32))
# ('Step: ', 116, 'A is: ', array([ 1.01547122], dtype=float32), ' b is: ', array([-0.42897081], dtype=float32))
# ('Loss: ', array([  8.23239970e-05], dtype=float32))
# ('Step: ', 117, 'A is: ', array([ 1.01542974], dtype=float32), ' b is: ', array([-0.42897227], dtype=float32))
# ('Loss: ', array([  3.83080078e-05], dtype=float32))
# ('Step: ', 118, 'A is: ', array([ 1.01541805], dtype=float32), ' b is: ', array([-0.42897269], dtype=float32))
# ('Loss: ', array([  3.10601899e-06], dtype=float32))
# ('Step: ', 119, 'A is: ', array([ 1.01547766], dtype=float32), ' b is: ', array([-0.42897049], dtype=float32))
# ('Loss: ', array([  8.80981679e-05], dtype=float32))
# ('Step: ', 120, 'A is: ', array([ 1.01552856], dtype=float32), ' b is: ', array([-0.42896861], dtype=float32))
# ('Loss: ', array([  6.40822982e-05], dtype=float32))
# ('Step: ', 121, 'A is: ', array([ 1.0155642], dtype=float32), ' b is: ', array([-0.4289673], dtype=float32))
# ('Loss: ', array([  3.11039039e-05], dtype=float32))
# ('Step: ', 122, 'A is: ', array([ 1.01545632], dtype=float32), ' b is: ', array([-0.42897105], dtype=float32))
# ('Loss: ', array([ 0.00024456], dtype=float32))
# ('Step: ', 123, 'A is: ', array([ 1.01537204], dtype=float32), ' b is: ', array([-0.42897397], dtype=float32))
# ('Loss: ', array([ 0.00015004], dtype=float32))
# ('Step: ', 124, 'A is: ', array([ 1.01543975], dtype=float32), ' b is: ', array([-0.42897147], dtype=float32))
# ('Loss: ', array([ 0.00011356], dtype=float32))
# ('Step: ', 125, 'A is: ', array([ 1.01548338], dtype=float32), ' b is: ', array([-0.42896986], dtype=float32))
# ('Loss: ', array([  4.64176410e-05], dtype=float32))
# ('Step: ', 126, 'A is: ', array([ 1.01550615], dtype=float32), ' b is: ', array([-0.42896903], dtype=float32))
# ('Loss: ', array([  1.24106336e-05], dtype=float32))
# ('Step: ', 127, 'A is: ', array([ 1.01540506], dtype=float32), ' b is: ', array([-0.42897254], dtype=float32))
# ('Loss: ', array([ 0.0002143], dtype=float32))
# ('Step: ', 128, 'A is: ', array([ 1.01539719], dtype=float32), ' b is: ', array([-0.42897281], dtype=float32))
# ('Loss: ', array([  1.38943142e-06], dtype=float32))
# ('Step: ', 129, 'A is: ', array([ 1.01536882], dtype=float32), ' b is: ', array([-0.42897382], dtype=float32))
# ('Loss: ', array([  1.78648625e-05], dtype=float32))
# ('Step: ', 130, 'A is: ', array([ 1.01542807], dtype=float32), ' b is: ', array([-0.42897165], dtype=float32))
# ('Loss: ', array([  8.62461457e-05], dtype=float32))
# ('Step: ', 131, 'A is: ', array([ 1.01541114], dtype=float32), ' b is: ', array([-0.42897224], dtype=float32))
# ('Loss: ', array([  6.44490137e-06], dtype=float32))
# ('Step: ', 132, 'A is: ', array([ 1.01544213], dtype=float32), ' b is: ', array([-0.42897111], dtype=float32))
# ('Loss: ', array([  2.30293372e-05], dtype=float32))
# ('Step: ', 133, 'A is: ', array([ 1.01548409], dtype=float32), ' b is: ', array([-0.42896956], dtype=float32))
# ('Loss: ', array([  4.28753592e-05], dtype=float32))
# ('Step: ', 134, 'A is: ', array([ 1.01544058], dtype=float32), ' b is: ', array([-0.42897111], dtype=float32))
# ('Loss: ', array([  4.22035955e-05], dtype=float32))
# ('Step: ', 135, 'A is: ', array([ 1.01546979], dtype=float32), ' b is: ', array([-0.42897004], dtype=float32))
# ('Loss: ', array([  2.04859280e-05], dtype=float32))
# ('Step: ', 136, 'A is: ', array([ 1.01545596], dtype=float32), ' b is: ', array([-0.42897055], dtype=float32))
# ('Loss: ', array([  4.42599776e-06], dtype=float32))
# ('Step: ', 137, 'A is: ', array([ 1.01539314], dtype=float32), ' b is: ', array([-0.42897275], dtype=float32))
# ('Loss: ', array([  8.55743565e-05], dtype=float32))
# ('Step: ', 138, 'A is: ', array([ 1.01535022], dtype=float32), ' b is: ', array([-0.42897427], dtype=float32))
# ('Loss: ', array([  4.02685291e-05], dtype=float32))
# ('Step: ', 139, 'A is: ', array([ 1.01529622], dtype=float32), ' b is: ', array([-0.42897618], dtype=float32))
# ('Loss: ', array([  6.27154950e-05], dtype=float32))
# ('Step: ', 140, 'A is: ', array([ 1.01537251], dtype=float32), ' b is: ', array([-0.42897338], dtype=float32))
# ('Loss: ', array([ 0.00014389], dtype=float32))
# ('Step: ', 141, 'A is: ', array([ 1.01534116], dtype=float32), ' b is: ', array([-0.42897448], dtype=float32))
# ('Loss: ', array([  2.16413209e-05], dtype=float32))
# ('Step: ', 142, 'A is: ', array([ 1.01541209], dtype=float32), ' b is: ', array([-0.42897186], dtype=float32))
# ('Loss: ', array([ 0.00012459], dtype=float32))
# ('Step: ', 143, 'A is: ', array([ 1.01544297], dtype=float32), ' b is: ', array([-0.42897072], dtype=float32))
# ('Loss: ', array([  2.28101853e-05], dtype=float32))
# ('Step: ', 144, 'A is: ', array([ 1.01536095], dtype=float32), ' b is: ', array([-0.42897359], dtype=float32))
# ('Loss: ', array([ 0.00014234], dtype=float32))
# ('Step: ', 145, 'A is: ', array([ 1.01536405], dtype=float32), ' b is: ', array([-0.42897347], dtype=float32))
# ('Loss: ', array([  2.14819011e-07], dtype=float32))
# ('Step: ', 146, 'A is: ', array([ 1.0153451], dtype=float32), ' b is: ', array([-0.42897415], dtype=float32))
# ('Loss: ', array([  8.08752156e-06], dtype=float32))
# ('Step: ', 147, 'A is: ', array([ 1.01529193], dtype=float32), ' b is: ', array([-0.42897603], dtype=float32))
# ('Loss: ', array([  6.07672300e-05], dtype=float32))
# ('Step: ', 148, 'A is: ', array([ 1.01525569], dtype=float32), ' b is: ', array([-0.42897731], dtype=float32))
# ('Loss: ', array([  2.84403213e-05], dtype=float32))
# ('Step: ', 149, 'A is: ', array([ 1.01531279], dtype=float32), ' b is: ', array([-0.42897522], dtype=float32))
# ('Loss: ', array([  7.81217968e-05], dtype=float32))
# ('Step: ', 150, 'A is: ', array([ 1.0153892], dtype=float32), ' b is: ', array([-0.42897239], dtype=float32))
# ('Loss: ', array([ 0.00014457], dtype=float32))
# ('Step: ', 151, 'A is: ', array([ 1.0154556], dtype=float32), ' b is: ', array([-0.42896995], dtype=float32))
# ('Loss: ', array([ 0.00010957], dtype=float32))
# ('Step: ', 152, 'A is: ', array([ 1.01536572], dtype=float32), ' b is: ', array([-0.42897308], dtype=float32))
# ('Loss: ', array([ 0.00016981], dtype=float32))
# ('Step: ', 153, 'A is: ', array([ 1.0153532], dtype=float32), ' b is: ', array([-0.42897353], dtype=float32))
# ('Loss: ', array([  3.50104892e-06], dtype=float32))
# ('Step: ', 154, 'A is: ', array([ 1.0154084], dtype=float32), ' b is: ', array([-0.4289715], dtype=float32))
# ('Loss: ', array([  7.42267293e-05], dtype=float32))
# ('Step: ', 155, 'A is: ', array([ 1.01537824], dtype=float32), ' b is: ', array([-0.42897257], dtype=float32))
# ('Loss: ', array([  2.01934599e-05], dtype=float32))
# ('Step: ', 156, 'A is: ', array([ 1.01541686], dtype=float32), ' b is: ', array([-0.42897117], dtype=float32))
# ('Loss: ', array([  3.56864766e-05], dtype=float32))
# ('Step: ', 157, 'A is: ', array([ 1.01547539], dtype=float32), ' b is: ', array([-0.42896903], dtype=float32))
# ('Loss: ', array([  8.46242183e-05], dtype=float32))
# ('Step: ', 158, 'A is: ', array([ 1.01545656], dtype=float32), ' b is: ', array([-0.42896971], dtype=float32))
# ('Loss: ', array([  8.06583921e-06], dtype=float32))
# ('Step: ', 159, 'A is: ', array([ 1.01544476], dtype=float32), ' b is: ', array([-0.42897013], dtype=float32))
# ('Loss: ', array([  3.20768231e-06], dtype=float32))
# ('Step: ', 160, 'A is: ', array([ 1.01540744], dtype=float32), ' b is: ', array([-0.42897144], dtype=float32))
# ('Loss: ', array([  3.09127245e-05], dtype=float32))
# ('Step: ', 161, 'A is: ', array([ 1.0154351], dtype=float32), ' b is: ', array([-0.42897043], dtype=float32))
# ('Loss: ', array([  1.82376280e-05], dtype=float32))
# ('Step: ', 162, 'A is: ', array([ 1.01548457], dtype=float32), ' b is: ', array([-0.42896861], dtype=float32))
# ('Loss: ', array([  5.99965315e-05], dtype=float32))
# ('Step: ', 163, 'A is: ', array([ 1.01550055], dtype=float32), ' b is: ', array([-0.42896801], dtype=float32))
# ('Loss: ', array([  6.08215123e-06], dtype=float32))
# ('Step: ', 164, 'A is: ', array([ 1.01544321], dtype=float32), ' b is: ', array([-0.42897004], dtype=float32))
# ('Loss: ', array([  7.22678960e-05], dtype=float32))
# ('Step: ', 165, 'A is: ', array([ 1.01542389], dtype=float32), ' b is: ', array([-0.42897072], dtype=float32))
# ('Loss: ', array([  8.40518624e-06], dtype=float32))
# ('Step: ', 166, 'A is: ', array([ 1.01533926], dtype=float32), ' b is: ', array([-0.42897367], dtype=float32))
# ('Loss: ', array([ 0.00015051], dtype=float32))
# ('Step: ', 167, 'A is: ', array([ 1.01538372], dtype=float32), ' b is: ', array([-0.42897207], dtype=float32))
# ('Loss: ', array([  4.74630506e-05], dtype=float32))
# ('Step: ', 168, 'A is: ', array([ 1.0154357], dtype=float32), ' b is: ', array([-0.42897016], dtype=float32))
# ('Loss: ', array([  6.58037898e-05], dtype=float32))
# ('Step: ', 169, 'A is: ', array([ 1.01538873], dtype=float32), ' b is: ', array([-0.42897183], dtype=float32))
# ('Loss: ', array([  4.83873337e-05], dtype=float32))
# ('Step: ', 170, 'A is: ', array([ 1.01535487], dtype=float32), ' b is: ', array([-0.42897302], dtype=float32))
# ('Loss: ', array([  2.54129154e-05], dtype=float32))
# ('Step: ', 171, 'A is: ', array([ 1.01540983], dtype=float32), ' b is: ', array([-0.42897099], dtype=float32))
# ('Loss: ', array([  7.35381618e-05], dtype=float32))
# ('Step: ', 172, 'A is: ', array([ 1.01546299], dtype=float32), ' b is: ', array([-0.42896903], dtype=float32))
# ('Loss: ', array([  6.94423215e-05], dtype=float32))
# ('Step: ', 173, 'A is: ', array([ 1.01544058], dtype=float32), ' b is: ', array([-0.42896983], dtype=float32))
# ('Loss: ', array([  1.13331225e-05], dtype=float32))
# ('Step: ', 174, 'A is: ', array([ 1.01535034], dtype=float32), ' b is: ', array([-0.42897296], dtype=float32))
# ('Loss: ', array([ 0.00017065], dtype=float32))
# ('Step: ', 175, 'A is: ', array([ 1.01527512], dtype=float32), ' b is: ', array([-0.42897558], dtype=float32))
# ('Loss: ', array([ 0.0001187], dtype=float32))
# ('Step: ', 176, 'A is: ', array([ 1.01525116], dtype=float32), ' b is: ', array([-0.42897642], dtype=float32))
# ('Loss: ', array([  1.25048828e-05], dtype=float32))
# ('Step: ', 177, 'A is: ', array([ 1.01533532], dtype=float32), ' b is: ', array([-0.42897332], dtype=float32))
# ('Loss: ', array([ 0.00017542], dtype=float32))
# ('Step: ', 178, 'A is: ', array([ 1.01540458], dtype=float32), ' b is: ', array([-0.42897075], dtype=float32))
# ('Loss: ', array([ 0.00011841], dtype=float32))
# ('Step: ', 179, 'A is: ', array([ 1.01531458], dtype=float32), ' b is: ', array([-0.42897388], dtype=float32))
# ('Loss: ', array([ 0.00016881], dtype=float32))
# ('Step: ', 180, 'A is: ', array([ 1.01527047], dtype=float32), ' b is: ', array([-0.42897543], dtype=float32))
# ('Loss: ', array([  4.18573618e-05], dtype=float32))
# ('Step: ', 181, 'A is: ', array([ 1.01526356], dtype=float32), ' b is: ', array([-0.42897567], dtype=float32))
# ('Loss: ', array([  1.04128048e-06], dtype=float32))
# ('Step: ', 182, 'A is: ', array([ 1.01525235], dtype=float32), ' b is: ', array([-0.42897606], dtype=float32))
# ('Loss: ', array([  2.76626088e-06], dtype=float32))
# ('Step: ', 183, 'A is: ', array([ 1.01523757], dtype=float32), ' b is: ', array([-0.4289766], dtype=float32))
# ('Loss: ', array([  4.81122697e-06], dtype=float32))
# ('Step: ', 184, 'A is: ', array([ 1.01523995], dtype=float32), ' b is: ', array([-0.42897651], dtype=float32))
# ('Loss: ', array([  1.24509825e-07], dtype=float32))
# ('Step: ', 185, 'A is: ', array([ 1.01518583], dtype=float32), ' b is: ', array([-0.42897838], dtype=float32))
# ('Loss: ', array([  6.16326579e-05], dtype=float32))
# ('Step: ', 186, 'A is: ', array([ 1.01527846], dtype=float32), ' b is: ', array([-0.42897496], dtype=float32))
# ('Loss: ', array([ 0.00021157], dtype=float32))
# ('Step: ', 187, 'A is: ', array([ 1.01520944], dtype=float32), ' b is: ', array([-0.42897734], dtype=float32))
# ('Loss: ', array([  9.90911212e-05], dtype=float32))
# ('Step: ', 188, 'A is: ', array([ 1.01515758], dtype=float32), ' b is: ', array([-0.42897913], dtype=float32))
# ('Loss: ', array([  5.63312824e-05], dtype=float32))
# ('Step: ', 189, 'A is: ', array([ 1.01517797], dtype=float32), ' b is: ', array([-0.42897841], dtype=float32))
# ('Loss: ', array([  9.30158785e-06], dtype=float32))
# ('Step: ', 190, 'A is: ', array([ 1.01512992], dtype=float32), ' b is: ', array([-0.42898008], dtype=float32))
# ('Loss: ', array([  4.82017640e-05], dtype=float32))
# ('Step: ', 191, 'A is: ', array([ 1.01521969], dtype=float32), ' b is: ', array([-0.4289768], dtype=float32))
# ('Loss: ', array([ 0.00019621], dtype=float32))
# ('Step: ', 192, 'A is: ', array([ 1.01530969], dtype=float32), ' b is: ', array([-0.42897347], dtype=float32))
# ('Loss: ', array([ 0.0002011], dtype=float32))
# ('Step: ', 193, 'A is: ', array([ 1.01528299], dtype=float32), ' b is: ', array([-0.42897442], dtype=float32))
# ('Loss: ', array([  1.56637725e-05], dtype=float32))
# ('Step: ', 194, 'A is: ', array([ 1.01533592], dtype=float32), ' b is: ', array([-0.42897248], dtype=float32))
# ('Loss: ', array([  6.72662281e-05], dtype=float32))
# ('Step: ', 195, 'A is: ', array([ 1.01531315], dtype=float32), ' b is: ', array([-0.42897329], dtype=float32))
# ('Loss: ', array([  1.14360919e-05], dtype=float32))
# ('Step: ', 196, 'A is: ', array([ 1.01528859], dtype=float32), ' b is: ', array([-0.42897415], dtype=float32))
# ('Loss: ', array([  1.32439309e-05], dtype=float32))
# ('Step: ', 197, 'A is: ', array([ 1.015257], dtype=float32), ' b is: ', array([-0.42897525], dtype=float32))
# ('Loss: ', array([  2.16235785e-05], dtype=float32))
# ('Step: ', 198, 'A is: ', array([ 1.01525092], dtype=float32), ' b is: ', array([-0.42897546], dtype=float32))
# ('Loss: ', array([  8.13921361e-07], dtype=float32))
# ('Step: ', 199, 'A is: ', array([ 1.01532269], dtype=float32), ' b is: ', array([-0.42897284], dtype=float32))
# ('Loss: ', array([ 0.00012535], dtype=float32))
# ('Step: ', 200, 'A is: ', array([ 1.01525068], dtype=float32), ' b is: ', array([-0.42897534], dtype=float32))
# ('Loss: ', array([ 0.00010873], dtype=float32))
# ('Step: ', 201, 'A is: ', array([ 1.01533246], dtype=float32), ' b is: ', array([-0.42897233], dtype=float32))
# ('Loss: ', array([ 0.00016492], dtype=float32))
# ('Step: ', 202, 'A is: ', array([ 1.01531982], dtype=float32), ' b is: ', array([-0.42897278], dtype=float32))
# ('Loss: ', array([  3.60168997e-06], dtype=float32))
# ('Step: ', 203, 'A is: ', array([ 1.01532924], dtype=float32), ' b is: ', array([-0.42897245], dtype=float32))
# ('Loss: ', array([  2.05182369e-06], dtype=float32))
# ('Step: ', 204, 'A is: ', array([ 1.01531029], dtype=float32), ' b is: ', array([-0.42897314], dtype=float32))
# ('Loss: ', array([  7.94710650e-06], dtype=float32))
# ('Step: ', 205, 'A is: ', array([ 1.01529706], dtype=float32), ' b is: ', array([-0.42897362], dtype=float32))
# ('Loss: ', array([  3.86702959e-06], dtype=float32))
# ('Step: ', 206, 'A is: ', array([ 1.01531005], dtype=float32), ' b is: ', array([-0.42897314], dtype=float32))
# ('Loss: ', array([  3.86702959e-06], dtype=float32))
# ('Step: ', 207, 'A is: ', array([ 1.01530361], dtype=float32), ' b is: ', array([-0.42897338], dtype=float32))
# ('Loss: ', array([  9.16785211e-07], dtype=float32))
# ('Step: ', 208, 'A is: ', array([ 1.01537251], dtype=float32), ' b is: ', array([-0.42897084], dtype=float32))
# ('Loss: ', array([ 0.00011654], dtype=float32))
# ('Step: ', 209, 'A is: ', array([ 1.01534116], dtype=float32), ' b is: ', array([-0.42897195], dtype=float32))
# ('Loss: ', array([  2.16590706e-05], dtype=float32))
# ('Step: ', 210, 'A is: ', array([ 1.01532173], dtype=float32), ' b is: ', array([-0.42897263], dtype=float32))
# ('Loss: ', array([  8.41624933e-06], dtype=float32))
# ('Step: ', 211, 'A is: ', array([ 1.01532292], dtype=float32), ' b is: ', array([-0.4289726], dtype=float32))
# ('Loss: ', array([  2.94676283e-08], dtype=float32))
# ('Step: ', 212, 'A is: ', array([ 1.01538265], dtype=float32), ' b is: ', array([-0.42897043], dtype=float32))
# ('Loss: ', array([  8.67783674e-05], dtype=float32))
# ('Step: ', 213, 'A is: ', array([ 1.01530206], dtype=float32), ' b is: ', array([-0.42897323], dtype=float32))
# ('Loss: ', array([ 0.00013621], dtype=float32))
# ('Step: ', 214, 'A is: ', array([ 1.01529014], dtype=float32), ' b is: ', array([-0.42897364], dtype=float32))
# ('Loss: ', array([  3.13972487e-06], dtype=float32))
# ('Step: ', 215, 'A is: ', array([ 1.01535726], dtype=float32), ' b is: ', array([-0.42897117], dtype=float32))
# ('Loss: ', array([ 0.00010993], dtype=float32))
# ('Step: ', 216, 'A is: ', array([ 1.01528084], dtype=float32), ' b is: ', array([-0.42897382], dtype=float32))
# ('Loss: ', array([ 0.00012234], dtype=float32))
# ('Step: ', 217, 'A is: ', array([ 1.01528704], dtype=float32), ' b is: ', array([-0.42897362], dtype=float32))
# ('Loss: ', array([  8.77047569e-07], dtype=float32))
# ('Step: ', 218, 'A is: ', array([ 1.01536727], dtype=float32), ' b is: ', array([-0.42897066], dtype=float32))
# ('Loss: ', array([ 0.00015919], dtype=float32))
# ('Step: ', 219, 'A is: ', array([ 1.01532853], dtype=float32), ' b is: ', array([-0.42897204], dtype=float32))
# ('Loss: ', array([  3.28729075e-05], dtype=float32))
# ('Step: ', 220, 'A is: ', array([ 1.01540256], dtype=float32), ' b is: ', array([-0.42896929], dtype=float32))
# ('Loss: ', array([ 0.00013595], dtype=float32))
# ('Step: ', 221, 'A is: ', array([ 1.01538968], dtype=float32), ' b is: ', array([-0.42896974], dtype=float32))
# ('Loss: ', array([  3.77012475e-06], dtype=float32))
# ('Step: ', 222, 'A is: ', array([ 1.01545346], dtype=float32), ' b is: ', array([-0.42896739], dtype=float32))
# ('Loss: ', array([ 0.00010069], dtype=float32))
# ('Step: ', 223, 'A is: ', array([ 1.01544213], dtype=float32), ' b is: ', array([-0.4289678], dtype=float32))
# ('Loss: ', array([  2.95987411e-06], dtype=float32))
# ('Step: ', 224, 'A is: ', array([ 1.01548409], dtype=float32), ' b is: ', array([-0.42896625], dtype=float32))
# ('Loss: ', array([  4.28254170e-05], dtype=float32))
# ('Step: ', 225, 'A is: ', array([ 1.01551592], dtype=float32), ' b is: ', array([-0.42896509], dtype=float32))
# ('Loss: ', array([  2.44604926e-05], dtype=float32))
# ('Step: ', 226, 'A is: ', array([ 1.01544762], dtype=float32), ' b is: ', array([-0.42896751], dtype=float32))
# ('Loss: ', array([ 0.00010154], dtype=float32))
# ('Step: ', 227, 'A is: ', array([ 1.01543319], dtype=float32), ' b is: ', array([-0.42896801], dtype=float32))
# ('Loss: ', array([  4.78615766e-06], dtype=float32))
# ('Step: ', 228, 'A is: ', array([ 1.0154829], dtype=float32), ' b is: ', array([-0.42896619], dtype=float32))
# ('Loss: ', array([  6.06780523e-05], dtype=float32))
# ('Step: ', 229, 'A is: ', array([ 1.0155201], dtype=float32), ' b is: ', array([-0.42896482], dtype=float32))
# ('Loss: ', array([  3.37092788e-05], dtype=float32))
# ('Step: ', 230, 'A is: ', array([ 1.01545107], dtype=float32), ' b is: ', array([-0.42896724], dtype=float32))
# ('Loss: ', array([ 0.00010354], dtype=float32))
# ('Step: ', 231, 'A is: ', array([ 1.0153805], dtype=float32), ' b is: ', array([-0.42896971], dtype=float32))
# ('Loss: ', array([ 0.00010675], dtype=float32))
# ('Step: ', 232, 'A is: ', array([ 1.01534235], dtype=float32), ' b is: ', array([-0.42897105], dtype=float32))
# ('Loss: ', array([  3.18529819e-05], dtype=float32))
# ('Step: ', 233, 'A is: ', array([ 1.01529372], dtype=float32), ' b is: ', array([-0.42897275], dtype=float32))
# ('Loss: ', array([  5.09138081e-05], dtype=float32))
# ('Step: ', 234, 'A is: ', array([ 1.01536417], dtype=float32), ' b is: ', array([-0.42897016], dtype=float32))
# ('Loss: ', array([ 0.0001215], dtype=float32))
# ('Step: ', 235, 'A is: ', array([ 1.01533151], dtype=float32), ' b is: ', array([-0.42897132], dtype=float32))
# ('Loss: ', array([  2.35818006e-05], dtype=float32))
# ('Step: ', 236, 'A is: ', array([ 1.01531088], dtype=float32), ' b is: ', array([-0.42897207], dtype=float32))
# ('Loss: ', array([  9.47692024e-06], dtype=float32))
# ('Step: ', 237, 'A is: ', array([ 1.01536477], dtype=float32), ' b is: ', array([-0.4289701], dtype=float32))
# ('Loss: ', array([  6.99518714e-05], dtype=float32))
# ('Step: ', 238, 'A is: ', array([ 1.01534152], dtype=float32), ' b is: ', array([-0.42897093], dtype=float32))
# ('Loss: ', array([  1.19843207e-05], dtype=float32))
# ('Step: ', 239, 'A is: ', array([ 1.0153476], dtype=float32), ' b is: ', array([-0.42897072], dtype=float32))
# ('Loss: ', array([  8.41686415e-07], dtype=float32))
# ('Step: ', 240, 'A is: ', array([ 1.01532578], dtype=float32), ' b is: ', array([-0.4289715], dtype=float32))
# ('Loss: ', array([  1.06129446e-05], dtype=float32))
# ('Step: ', 241, 'A is: ', array([ 1.01531279], dtype=float32), ' b is: ', array([-0.42897195], dtype=float32))
# ('Loss: ', array([  3.75532545e-06], dtype=float32))
# ('Step: ', 242, 'A is: ', array([ 1.01536131], dtype=float32), ' b is: ', array([-0.42897019], dtype=float32))
# ('Loss: ', array([  5.62740352e-05], dtype=float32))
# ('Step: ', 243, 'A is: ', array([ 1.01543057], dtype=float32), ' b is: ', array([-0.42896762], dtype=float32))
# ('Loss: ', array([ 0.00011882], dtype=float32))
# ('Step: ', 244, 'A is: ', array([ 1.01546645], dtype=float32), ' b is: ', array([-0.42896631], dtype=float32))
# ('Loss: ', array([  3.11039039e-05], dtype=float32))
# ('Step: ', 245, 'A is: ', array([ 1.01550484], dtype=float32), ' b is: ', array([-0.42896491], dtype=float32))
# ('Loss: ', array([  3.57320678e-05], dtype=float32))
# ('Step: ', 246, 'A is: ', array([ 1.0155375], dtype=float32), ' b is: ', array([-0.42896372], dtype=float32))
# ('Loss: ', array([  2.58765394e-05], dtype=float32))
# ('Step: ', 247, 'A is: ', array([ 1.01556659], dtype=float32), ' b is: ', array([-0.42896265], dtype=float32))
# ('Loss: ', array([  2.05723481e-05], dtype=float32))
# ('Step: ', 248, 'A is: ', array([ 1.01551127], dtype=float32), ' b is: ', array([-0.42896461], dtype=float32))
# ('Loss: ', array([  6.80821395e-05], dtype=float32))
# ('Step: ', 249, 'A is: ', array([ 1.01543939], dtype=float32), ' b is: ', array([-0.42896715], dtype=float32))
# ('Loss: ', array([ 0.00011182], dtype=float32))
# ('Step: ', 250, 'A is: ', array([ 1.01548302], dtype=float32), ' b is: ', array([-0.42896554], dtype=float32))
# ('Loss: ', array([  4.64696350e-05], dtype=float32))
# ('Step: ', 251, 'A is: ', array([ 1.01538432], dtype=float32), ' b is: ', array([-0.42896897], dtype=float32))
# ('Loss: ', array([ 0.00020404], dtype=float32))
# ('Step: ', 252, 'A is: ', array([ 1.01543486], dtype=float32), ' b is: ', array([-0.42896712], dtype=float32))
# ('Loss: ', array([  6.22330699e-05], dtype=float32))
# ('Step: ', 253, 'A is: ', array([ 1.01537967], dtype=float32), ' b is: ', array([-0.42896906], dtype=float32))
# ('Loss: ', array([  6.63309038e-05], dtype=float32))
# ('Step: ', 254, 'A is: ', array([ 1.01542318], dtype=float32), ' b is: ', array([-0.42896748], dtype=float32))
# ('Loss: ', array([  4.57185706e-05], dtype=float32))
# ('Step: ', 255, 'A is: ', array([ 1.01539886], dtype=float32), ' b is: ', array([-0.42896834], dtype=float32))
# ('Loss: ', array([  1.32439309e-05], dtype=float32))
# ('Step: ', 256, 'A is: ', array([ 1.01544857], dtype=float32), ' b is: ', array([-0.42896652], dtype=float32))
# ('Loss: ', array([  6.01739484e-05], dtype=float32))
# ('Step: ', 257, 'A is: ', array([ 1.01550627], dtype=float32), ' b is: ', array([-0.42896438], dtype=float32))
# ('Loss: ', array([  8.26358009e-05], dtype=float32))
# ('Step: ', 258, 'A is: ', array([ 1.01543951], dtype=float32), ' b is: ', array([-0.42896673], dtype=float32))
# ('Loss: ', array([  9.69760295e-05], dtype=float32))
# ('Step: ', 259, 'A is: ', array([ 1.01542628], dtype=float32), ' b is: ', array([-0.42896721], dtype=float32))
# ('Loss: ', array([  3.98798511e-06], dtype=float32))
# ('Step: ', 260, 'A is: ', array([ 1.01547706], dtype=float32), ' b is: ', array([-0.42896533], dtype=float32))
# ('Loss: ', array([  6.31391449e-05], dtype=float32))
# ('Step: ', 261, 'A is: ', array([ 1.01540649], dtype=float32), ' b is: ', array([-0.4289678], dtype=float32))
# ('Loss: ', array([ 0.00010723], dtype=float32))
# ('Step: ', 262, 'A is: ', array([ 1.01545632], dtype=float32), ' b is: ', array([-0.42896599], dtype=float32))
# ('Loss: ', array([  6.05592504e-05], dtype=float32))
# ('Step: ', 263, 'A is: ', array([ 1.01537776], dtype=float32), ' b is: ', array([-0.42896873], dtype=float32))
# ('Loss: ', array([ 0.00013119], dtype=float32))
# ('Step: ', 264, 'A is: ', array([ 1.0154165], dtype=float32), ' b is: ', array([-0.42896733], dtype=float32))
# ('Loss: ', array([  3.58005091e-05], dtype=float32))
# ('Step: ', 265, 'A is: ', array([ 1.01537538], dtype=float32), ' b is: ', array([-0.42896879], dtype=float32))
# ('Loss: ', array([  3.72296236e-05], dtype=float32))
# ('Step: ', 266, 'A is: ', array([ 1.01541436], dtype=float32), ' b is: ', array([-0.42896736], dtype=float32))
# ('Loss: ', array([  3.64654843e-05], dtype=float32))
# ('Step: ', 267, 'A is: ', array([ 1.01546299], dtype=float32), ' b is: ', array([-0.42896557], dtype=float32))
# ('Loss: ', array([  5.77429309e-05], dtype=float32))
# ('Step: ', 268, 'A is: ', array([ 1.01547956], dtype=float32), ' b is: ', array([-0.42896497], dtype=float32))
# ('Loss: ', array([  6.53235475e-06], dtype=float32))
# ('Step: ', 269, 'A is: ', array([ 1.01551592], dtype=float32), ' b is: ', array([-0.42896363], dtype=float32))
# ('Loss: ', array([  3.21767438e-05], dtype=float32))
# ('Step: ', 270, 'A is: ', array([ 1.01543903], dtype=float32), ' b is: ', array([-0.42896631], dtype=float32))
# ('Loss: ', array([ 0.00012737], dtype=float32))
# ('Step: ', 271, 'A is: ', array([ 1.01549816], dtype=float32), ' b is: ', array([-0.42896414], dtype=float32))
# ('Loss: ', array([  8.66717892e-05], dtype=float32))
# ('Step: ', 272, 'A is: ', array([ 1.01545513], dtype=float32), ' b is: ', array([-0.42896566], dtype=float32))
# ('Loss: ', array([  4.13161615e-05], dtype=float32))
# ('Step: ', 273, 'A is: ', array([ 1.0154078], dtype=float32), ' b is: ', array([-0.42896733], dtype=float32))
# ('Loss: ', array([  4.92937434e-05], dtype=float32))
# ('Step: ', 274, 'A is: ', array([ 1.01540351], dtype=float32), ' b is: ', array([-0.42896748], dtype=float32))
# ('Loss: ', array([  4.15617251e-07], dtype=float32))
# ('Step: ', 275, 'A is: ', array([ 1.01539993], dtype=float32), ' b is: ', array([-0.4289676], dtype=float32))
# ('Loss: ', array([  2.95494829e-07], dtype=float32))
# ('Step: ', 276, 'A is: ', array([ 1.01537108], dtype=float32), ' b is: ', array([-0.42896861], dtype=float32))
# ('Loss: ', array([  1.84664132e-05], dtype=float32))
# ('Step: ', 277, 'A is: ', array([ 1.01542616], dtype=float32), ' b is: ', array([-0.42896658], dtype=float32))
# ('Loss: ', array([  7.40296673e-05], dtype=float32))
# ('Step: ', 278, 'A is: ', array([ 1.01540136], dtype=float32), ' b is: ', array([-0.42896748], dtype=float32))
# ('Loss: ', array([  1.37625648e-05], dtype=float32))
# ('Step: ', 279, 'A is: ', array([ 1.0153805], dtype=float32), ' b is: ', array([-0.42896822], dtype=float32))
# ('Loss: ', array([  9.76085721e-06], dtype=float32))
# ('Step: ', 280, 'A is: ', array([ 1.01533401], dtype=float32), ' b is: ', array([-0.42896986], dtype=float32))
# ('Loss: ', array([  4.68605176e-05], dtype=float32))
# ('Step: ', 281, 'A is: ', array([ 1.01539838], dtype=float32), ' b is: ', array([-0.42896751], dtype=float32))
# ('Loss: ', array([ 0.00010181], dtype=float32))
# ('Step: ', 282, 'A is: ', array([ 1.01534772], dtype=float32), ' b is: ', array([-0.42896929], dtype=float32))
# ('Loss: ', array([  5.58741194e-05], dtype=float32))
# ('Step: ', 283, 'A is: ', array([ 1.01534474], dtype=float32), ' b is: ', array([-0.42896941], dtype=float32))
# ('Loss: ', array([  1.94126187e-07], dtype=float32))
# ('Step: ', 284, 'A is: ', array([ 1.01537931], dtype=float32), ' b is: ', array([-0.42896816], dtype=float32))
# ('Loss: ', array([  2.83183908e-05], dtype=float32))
# ('Step: ', 285, 'A is: ', array([ 1.01543057], dtype=float32), ' b is: ', array([-0.42896628], dtype=float32))
# ('Loss: ', array([  6.40822982e-05], dtype=float32))
# ('Step: ', 286, 'A is: ', array([ 1.015342], dtype=float32), ' b is: ', array([-0.42896935], dtype=float32))
# ('Loss: ', array([ 0.00016453], dtype=float32))
# ('Step: ', 287, 'A is: ', array([ 1.01533055], dtype=float32), ' b is: ', array([-0.42896977], dtype=float32))
# ('Loss: ', array([  2.95331483e-06], dtype=float32))
# ('Step: ', 288, 'A is: ', array([ 1.01539552], dtype=float32), ' b is: ', array([-0.42896739], dtype=float32))
# ('Loss: ', array([ 0.00010335], dtype=float32))
# ('Step: ', 289, 'A is: ', array([ 1.01536047], dtype=float32), ' b is: ', array([-0.42896864], dtype=float32))
# ('Loss: ', array([  2.70737801e-05], dtype=float32))
# ('Step: ', 290, 'A is: ', array([ 1.0154146], dtype=float32), ' b is: ', array([-0.42896664], dtype=float32))
# ('Loss: ', array([  7.12338951e-05], dtype=float32))
# ('Step: ', 291, 'A is: ', array([ 1.0154773], dtype=float32), ' b is: ', array([-0.42896432], dtype=float32))
# ('Loss: ', array([  9.75026633e-05], dtype=float32))
# ('Step: ', 292, 'A is: ', array([ 1.01541519], dtype=float32), ' b is: ', array([-0.42896649], dtype=float32))
# ('Loss: ', array([  8.38539563e-05], dtype=float32))
# ('Step: ', 293, 'A is: ', array([ 1.01532769], dtype=float32), ' b is: ', array([-0.42896953], dtype=float32))
# ('Loss: ', array([ 0.00016006], dtype=float32))
# ('Step: ', 294, 'A is: ', array([ 1.01527727], dtype=float32), ' b is: ', array([-0.42897129], dtype=float32))
# ('Loss: ', array([  5.45138064e-05], dtype=float32))
# ('Step: ', 295, 'A is: ', array([ 1.01535761], dtype=float32), ' b is: ', array([-0.42896834], dtype=float32))
# ('Loss: ', array([ 0.00015972], dtype=float32))
# ('Step: ', 296, 'A is: ', array([ 1.01542485], dtype=float32), ' b is: ', array([-0.42896587], dtype=float32))
# ('Loss: ', array([ 0.00011166], dtype=float32))
# ('Step: ', 297, 'A is: ', array([ 1.01539207], dtype=float32), ' b is: ', array([-0.42896703], dtype=float32))
# ...
# ('Step: ', 903, 'A is: ', array([ 1.01552975], dtype=float32), ' b is: ', array([-0.42894101], dtype=float32))
# ('Loss: ', array([  2.78131665e-05], dtype=float32))
# ('Step: ', 904, 'A is: ', array([ 1.01546752], dtype=float32), ' b is: ', array([-0.42894322], dtype=float32))
# ('Loss: ', array([  8.49403441e-05], dtype=float32))
# ('Step: ', 905, 'A is: ', array([ 1.0154978], dtype=float32), ' b is: ', array([-0.42894211], dtype=float32))
# ('Loss: ', array([  2.20334950e-05], dtype=float32))
# ('Step: ', 906, 'A is: ', array([ 1.01547945], dtype=float32), ' b is: ', array([-0.42894277], dtype=float32))
# ('Loss: ', array([  7.76534216e-06], dtype=float32))
# ('Step: ', 907, 'A is: ', array([ 1.01550794], dtype=float32), ' b is: ', array([-0.42894173], dtype=float32))
# ('Loss: ', array([  1.94967470e-05], dtype=float32))
# ('Step: ', 908, 'A is: ', array([ 1.01552427], dtype=float32), ' b is: ', array([-0.42894113], dtype=float32))
# ('Loss: ', array([  6.31962030e-06], dtype=float32))
# ('Step: ', 909, 'A is: ', array([ 1.01553142], dtype=float32), ' b is: ', array([-0.42894086], dtype=float32))
# ('Loss: ', array([  1.22381607e-06], dtype=float32))
# ('Step: ', 910, 'A is: ', array([ 1.01547599], dtype=float32), ' b is: ', array([-0.42894283], dtype=float32))
# ('Loss: ', array([  6.80506637e-05], dtype=float32))
# ('Step: ', 911, 'A is: ', array([ 1.01544595], dtype=float32), ' b is: ', array([-0.4289439], dtype=float32))
# ('Loss: ', array([  2.02964438e-05], dtype=float32))
# ('Step: ', 912, 'A is: ', array([ 1.0154742], dtype=float32), ' b is: ', array([-0.42894286], dtype=float32))
# ('Loss: ', array([  1.91279432e-05], dtype=float32))
# ('Step: ', 913, 'A is: ', array([ 1.01542091], dtype=float32), ' b is: ', array([-0.42894474], dtype=float32))
# ('Loss: ', array([  6.23233791e-05], dtype=float32))
# ('Step: ', 914, 'A is: ', array([ 1.01533377], dtype=float32), ' b is: ', array([-0.42894775], dtype=float32))
# ('Loss: ', array([ 0.00015905], dtype=float32))
# ('Step: ', 915, 'A is: ', array([ 1.01539433], dtype=float32), ' b is: ', array([-0.42894551], dtype=float32))
# ('Loss: ', array([  8.93197430e-05], dtype=float32))
# ('Step: ', 916, 'A is: ', array([ 1.01534414], dtype=float32), ' b is: ', array([-0.42894727], dtype=float32))
# ('Loss: ', array([  5.46829287e-05], dtype=float32))
# ('Step: ', 917, 'A is: ', array([ 1.01537871], dtype=float32), ' b is: ', array([-0.42894602], dtype=float32))
# ('Loss: ', array([  2.82575238e-05], dtype=float32))
# ('Step: ', 918, 'A is: ', array([ 1.01543128], dtype=float32), ' b is: ', array([-0.42894408], dtype=float32))
# ('Loss: ', array([  6.73288159e-05], dtype=float32))
# ('Step: ', 919, 'A is: ', array([ 1.01539314], dtype=float32), ' b is: ', array([-0.42894542], dtype=float32))
# ('Loss: ', array([  3.21334810e-05], dtype=float32))
# ('Step: ', 920, 'A is: ', array([ 1.01544869], dtype=float32), ' b is: ', array([-0.42894337], dtype=float32))
# ('Loss: ', array([  7.56466761e-05], dtype=float32))
# ('Step: ', 921, 'A is: ', array([ 1.01542842], dtype=float32), ' b is: ', array([-0.42894408], dtype=float32))
# ('Loss: ', array([  9.31322575e-06], dtype=float32))
# ('Step: ', 922, 'A is: ', array([ 1.01545668], dtype=float32), ' b is: ', array([-0.42894304], dtype=float32))
# ('Loss: ', array([  1.91112631e-05], dtype=float32))
# ('Step: ', 923, 'A is: ', array([ 1.01542699], dtype=float32), ' b is: ', array([-0.42894408], dtype=float32))
# ('Loss: ', array([  1.98350790e-05], dtype=float32))
# ('Step: ', 924, 'A is: ', array([ 1.01548517], dtype=float32), ' b is: ', array([-0.42894194], dtype=float32))
# ('Loss: ', array([  8.37142870e-05], dtype=float32))
# ('Step: ', 925, 'A is: ', array([ 1.01541317], dtype=float32), ' b is: ', array([-0.42894447], dtype=float32))
# ('Loss: ', array([ 0.00011174], dtype=float32))
# ('Step: ', 926, 'A is: ', array([ 1.01547086], dtype=float32), ' b is: ', array([-0.42894235], dtype=float32))
# ('Loss: ', array([  8.19782435e-05], dtype=float32))
# ('Step: ', 927, 'A is: ', array([ 1.01550841], dtype=float32), ' b is: ', array([-0.42894098], dtype=float32))
# ('Loss: ', array([  3.43099273e-05], dtype=float32))
# ('Step: ', 928, 'A is: ', array([ 1.01546085], dtype=float32), ' b is: ', array([-0.42894268], dtype=float32))
# ('Loss: ', array([  5.03708761e-05], dtype=float32))
# ('Step: ', 929, 'A is: ', array([ 1.01548421], dtype=float32), ' b is: ', array([-0.42894182], dtype=float32))
# ('Loss: ', array([  1.30640728e-05], dtype=float32))
# ('Step: ', 930, 'A is: ', array([ 1.01553142], dtype=float32), ' b is: ', array([-0.42894009], dtype=float32))
# ('Loss: ', array([  5.49088327e-05], dtype=float32))
# ('Step: ', 931, 'A is: ', array([ 1.01543462], dtype=float32), ' b is: ', array([-0.42894346], dtype=float32))
# ('Loss: ', array([ 0.00019814], dtype=float32))
# ('Step: ', 932, 'A is: ', array([ 1.01545537], dtype=float32), ' b is: ', array([-0.42894271], dtype=float32))
# ('Loss: ', array([  1.02556114e-05], dtype=float32))
# ('Step: ', 933, 'A is: ', array([ 1.0154978], dtype=float32), ' b is: ', array([-0.42894116], dtype=float32))
# ('Loss: ', array([  4.39055875e-05], dtype=float32))
# ('Step: ', 934, 'A is: ', array([ 1.01546156], dtype=float32), ' b is: ', array([-0.42894244], dtype=float32))
# ('Loss: ', array([  2.94665952e-05], dtype=float32))
# ('Step: ', 935, 'A is: ', array([ 1.01548481], dtype=float32), ' b is: ', array([-0.42894161], dtype=float32))
# ('Loss: ', array([  1.29402761e-05], dtype=float32))
# ('Step: ', 936, 'A is: ', array([ 1.01552284], dtype=float32), ' b is: ', array([-0.42894021], dtype=float32))
# ('Loss: ', array([  3.53227952e-05], dtype=float32))
# ('Step: ', 937, 'A is: ', array([ 1.01548541], dtype=float32), ' b is: ', array([-0.42894155], dtype=float32))
# ('Loss: ', array([  3.15094403e-05], dtype=float32))
# ('Step: ', 938, 'A is: ', array([ 1.015535], dtype=float32), ' b is: ', array([-0.42893973], dtype=float32))
# ('Loss: ', array([  6.08564733e-05], dtype=float32))
# ('Step: ', 939, 'A is: ', array([ 1.01542306], dtype=float32), ' b is: ', array([-0.4289436], dtype=float32))
# ('Loss: ', array([ 0.00026093], dtype=float32))
# ('Step: ', 940, 'A is: ', array([ 1.01541233], dtype=float32), ' b is: ', array([-0.42894399], dtype=float32))
# ('Loss: ', array([  2.65945346e-06], dtype=float32))
# ('Step: ', 941, 'A is: ', array([ 1.01536059], dtype=float32), ' b is: ', array([-0.42894581], dtype=float32))
# ('Loss: ', array([  5.81494678e-05], dtype=float32))
# ('Step: ', 942, 'A is: ', array([ 1.01531589], dtype=float32), ' b is: ', array([-0.42894739], dtype=float32))
# ('Loss: ', array([  4.34266440e-05], dtype=float32))
# ('Step: ', 943, 'A is: ', array([ 1.01538289], dtype=float32), ' b is: ', array([-0.42894492], dtype=float32))
# ('Loss: ', array([ 0.00011001], dtype=float32))
# ('Step: ', 944, 'A is: ', array([ 1.01542068], dtype=float32), ' b is: ', array([-0.42894354], dtype=float32))
# ('Loss: ', array([  3.41759915e-05], dtype=float32))
# ('Step: ', 945, 'A is: ', array([ 1.01538849], dtype=float32), ' b is: ', array([-0.42894468], dtype=float32))
# ('Loss: ', array([  2.31393060e-05], dtype=float32))
# ('Step: ', 946, 'A is: ', array([ 1.01535857], dtype=float32), ' b is: ', array([-0.42894575], dtype=float32))
# ('Loss: ', array([  1.98011148e-05], dtype=float32))
# ('Step: ', 947, 'A is: ', array([ 1.01535249], dtype=float32), ' b is: ', array([-0.42894596], dtype=float32))
# ('Loss: ', array([  8.55743565e-07], dtype=float32))
# ('Step: ', 948, 'A is: ', array([ 1.01535666], dtype=float32), ' b is: ', array([-0.42894581], dtype=float32))
# ('Loss: ', array([  4.10713255e-07], dtype=float32))
# ('Step: ', 949, 'A is: ', array([ 1.01533461], dtype=float32), ' b is: ', array([-0.42894658], dtype=float32))
# ('Loss: ', array([  1.08127133e-05], dtype=float32))
# ('Step: ', 950, 'A is: ', array([ 1.01530373], dtype=float32), ' b is: ', array([-0.42894769], dtype=float32))
# ('Loss: ', array([  2.09024038e-05], dtype=float32))
# ('Step: ', 951, 'A is: ', array([ 1.01526546], dtype=float32), ' b is: ', array([-0.42894903], dtype=float32))
# ('Loss: ', array([  3.18099374e-05], dtype=float32))
# ('Step: ', 952, 'A is: ', array([ 1.01525521], dtype=float32), ' b is: ', array([-0.42894939], dtype=float32))
# ('Loss: ', array([  2.33996252e-06], dtype=float32))
# ('Step: ', 953, 'A is: ', array([ 1.01533115], dtype=float32), ' b is: ', array([-0.42894658], dtype=float32))
# ('Loss: ', array([ 0.00014156], dtype=float32))
# ('Step: ', 954, 'A is: ', array([ 1.01537418], dtype=float32), ' b is: ', array([-0.428945], dtype=float32))
# ('Loss: ', array([  4.40827025e-05], dtype=float32))
# ('Step: ', 955, 'A is: ', array([ 1.01534522], dtype=float32), ' b is: ', array([-0.42894602], dtype=float32))
# ('Loss: ', array([  1.86142424e-05], dtype=float32))
# ('Step: ', 956, 'A is: ', array([ 1.01534116], dtype=float32), ' b is: ', array([-0.42894617], dtype=float32))
# ('Loss: ', array([  3.67886969e-07], dtype=float32))
# ('Step: ', 957, 'A is: ', array([ 1.01531196], dtype=float32), ' b is: ', array([-0.42894721], dtype=float32))
# ('Loss: ', array([  1.87296282e-05], dtype=float32))
# ('Step: ', 958, 'A is: ', array([ 1.01531851], dtype=float32), ' b is: ', array([-0.42894697], dtype=float32))
# ('Loss: ', array([  9.87496605e-07], dtype=float32))
# ('Step: ', 959, 'A is: ', array([ 1.01524699], dtype=float32), ' b is: ', array([-0.42894945], dtype=float32))
# ('Loss: ', array([ 0.00010707], dtype=float32))
# ('Step: ', 960, 'A is: ', array([ 1.01524103], dtype=float32), ' b is: ', array([-0.42894965], dtype=float32))
# ('Loss: ', array([  7.90008926e-07], dtype=float32))
# ('Step: ', 961, 'A is: ', array([ 1.01520872], dtype=float32), ' b is: ', array([-0.42895079], dtype=float32))
# ('Loss: ', array([  2.23930729e-05], dtype=float32))
# ('Step: ', 962, 'A is: ', array([ 1.01521015], dtype=float32), ' b is: ', array([-0.42895073], dtype=float32))
# ('Loss: ', array([  4.98002919e-08], dtype=float32))
# ('Step: ', 963, 'A is: ', array([ 1.01530027], dtype=float32), ' b is: ', array([-0.42894739], dtype=float32))
# ('Loss: ', array([ 0.00020073], dtype=float32))
# ('Step: ', 964, 'A is: ', array([ 1.01537836], dtype=float32), ' b is: ', array([-0.4289445], dtype=float32))
# ('Loss: ', array([ 0.00015107], dtype=float32))
# ('Step: ', 965, 'A is: ', array([ 1.01534867], dtype=float32), ' b is: ', array([-0.42894554], dtype=float32))
# ('Loss: ', array([  1.94799068e-05], dtype=float32))
# ('Step: ', 966, 'A is: ', array([ 1.01532793], dtype=float32), ' b is: ', array([-0.42894629], dtype=float32))
# ('Loss: ', array([  9.63019920e-06], dtype=float32))
# ('Step: ', 967, 'A is: ', array([ 1.01540315], dtype=float32), ' b is: ', array([-0.42894351], dtype=float32))
# ('Loss: ', array([ 0.0001407], dtype=float32))
# ('Step: ', 968, 'A is: ', array([ 1.01545715], dtype=float32), ' b is: ', array([-0.42894152], dtype=float32))
# ('Loss: ', array([  7.16530631e-05], dtype=float32))
# ('Step: ', 969, 'A is: ', array([ 1.01542735], dtype=float32), ' b is: ', array([-0.42894259], dtype=float32))
# ('Loss: ', array([  1.99541828e-05], dtype=float32))
# ('Step: ', 970, 'A is: ', array([ 1.01548672], dtype=float32), ' b is: ', array([-0.42894039], dtype=float32))
# ('Loss: ', array([  8.74191901e-05], dtype=float32))
# ('Step: ', 971, 'A is: ', array([ 1.01542294], dtype=float32), ' b is: ', array([-0.42894262], dtype=float32))
# ('Loss: ', array([  8.83848406e-05], dtype=float32))
# ('Step: ', 972, 'A is: ', array([ 1.01533544], dtype=float32), ' b is: ', array([-0.42894566], dtype=float32))
# ('Loss: ', array([ 0.0001603], dtype=float32))
# ('Step: ', 973, 'A is: ', array([ 1.01537395], dtype=float32), ' b is: ', array([-0.42894426], dtype=float32))
# ('Loss: ', array([  3.51190429e-05], dtype=float32))
# ('Step: ', 974, 'A is: ', array([ 1.01530886], dtype=float32), ' b is: ', array([-0.42894652], dtype=float32))
# ('Loss: ', array([  9.02958127e-05], dtype=float32))
# ('Step: ', 975, 'A is: ', array([ 1.01536667], dtype=float32), ' b is: ', array([-0.42894441], dtype=float32))
# ('Loss: ', array([  8.10483471e-05], dtype=float32))
# ('Step: ', 976, 'A is: ', array([ 1.01535928], dtype=float32), ' b is: ', array([-0.42894468], dtype=float32))
# ('Loss: ', array([  1.24075450e-06], dtype=float32))
# ('Step: ', 977, 'A is: ', array([ 1.0153327], dtype=float32), ' b is: ', array([-0.42894563], dtype=float32))
# ('Loss: ', array([  1.56939823e-05], dtype=float32))
# ('Step: ', 978, 'A is: ', array([ 1.01529384], dtype=float32), ' b is: ', array([-0.428947], dtype=float32))
# ('Loss: ', array([  3.27854796e-05], dtype=float32))
# ('Step: ', 979, 'A is: ', array([ 1.01527226], dtype=float32), ' b is: ', array([-0.42894778], dtype=float32))
# ('Loss: ', array([  1.02678314e-05], dtype=float32))
# ('Step: ', 980, 'A is: ', array([ 1.01531768], dtype=float32), ' b is: ', array([-0.42894614], dtype=float32))
# ('Loss: ', array([  4.89728736e-05], dtype=float32))
# ('Step: ', 981, 'A is: ', array([ 1.01536524], dtype=float32), ' b is: ', array([-0.42894441], dtype=float32))
# ('Loss: ', array([  5.42325179e-05], dtype=float32))
# ('Step: ', 982, 'A is: ', array([ 1.01528597], dtype=float32), ' b is: ', array([-0.42894715], dtype=float32))
# ('Loss: ', array([ 0.00013162], dtype=float32))
# ('Step: ', 983, 'A is: ', array([ 1.0153662], dtype=float32), ' b is: ', array([-0.4289442], dtype=float32))
# ('Loss: ', array([ 0.00015924], dtype=float32))
# ('Step: ', 984, 'A is: ', array([ 1.01532197], dtype=float32), ' b is: ', array([-0.42894575], dtype=float32))
# ('Loss: ', array([  4.26010374e-05], dtype=float32))
# ('Step: ', 985, 'A is: ', array([ 1.01539433], dtype=float32), ' b is: ', array([-0.4289431], dtype=float32))
# ('Loss: ', array([ 0.00012931], dtype=float32))
# ('Step: ', 986, 'A is: ', array([ 1.01534128], dtype=float32), ' b is: ', array([-0.42894498], dtype=float32))
# ('Loss: ', array([  6.08564733e-05], dtype=float32))
# ('Step: ', 987, 'A is: ', array([ 1.01530933], dtype=float32), ' b is: ', array([-0.42894611], dtype=float32))
# ('Loss: ', array([  2.24111282e-05], dtype=float32))
# ('Step: ', 988, 'A is: ', array([ 1.015288], dtype=float32), ' b is: ', array([-0.42894685], dtype=float32))
# ('Loss: ', array([  1.00852958e-05], dtype=float32))
# ('Step: ', 989, 'A is: ', array([ 1.01526737], dtype=float32), ' b is: ', array([-0.42894757], dtype=float32))
# ('Loss: ', array([  9.39489473e-06], dtype=float32))
# ('Step: ', 990, 'A is: ', array([ 1.01535404], dtype=float32), ' b is: ', array([-0.42894438], dtype=float32))
# ('Loss: ', array([ 0.00018687], dtype=float32))
# ('Step: ', 991, 'A is: ', array([ 1.01540124], dtype=float32), ' b is: ', array([-0.42894265], dtype=float32))
# ('Loss: ', array([  5.38119493e-05], dtype=float32))
# ('Step: ', 992, 'A is: ', array([ 1.01531744], dtype=float32), ' b is: ', array([-0.42894557], dtype=float32))
# ('Loss: ', array([ 0.00014743], dtype=float32))
# ('Step: ', 993, 'A is: ', array([ 1.01525593], dtype=float32), ' b is: ', array([-0.42894772], dtype=float32))
# ('Loss: ', array([  7.99872214e-05], dtype=float32))
# ('Step: ', 994, 'A is: ', array([ 1.01524448], dtype=float32), ' b is: ', array([-0.42894813], dtype=float32))
# ('Loss: ', array([  2.90760363e-06], dtype=float32))
# ('Step: ', 995, 'A is: ', array([ 1.01524031], dtype=float32), ' b is: ', array([-0.42894828], dtype=float32))
# ('Loss: ', array([  3.98580596e-07], dtype=float32))
# ('Step: ', 996, 'A is: ', array([ 1.01525807], dtype=float32), ' b is: ', array([-0.42894766], dtype=float32))
# ('Loss: ', array([  7.19168747e-06], dtype=float32))
# ('Step: ', 997, 'A is: ', array([ 1.01523674], dtype=float32), ' b is: ', array([-0.4289484], dtype=float32))
# ('Loss: ', array([  9.95247683e-06], dtype=float32))
# ('Step: ', 998, 'A is: ', array([ 1.01531541], dtype=float32), ' b is: ', array([-0.42894551], dtype=float32))
# ('Loss: ', array([ 0.00015187], dtype=float32))
# ('Step: ', 999, 'A is: ', array([ 1.01524866], dtype=float32), ' b is: ', array([-0.42894784], dtype=float32))
# ('Loss: ', array([  9.38461744e-05], dtype=float32))
# ('Step: ', 1000, 'A is: ', array([ 1.01524246], dtype=float32), ' b is: ', array([-0.42894804], dtype=float32))
# ('Loss: ', array([  8.69917130e-07], dtype=float32))

# %%
# Standard Deviation
print df.std()
# Out:
# power    863.299935
# temp       2.929614
# dtype: float64

# %%
df.shape[0]
# Out:
# 5760

# %% [markdown]
# # !! Not sure how are we getting these numbers - manually?

# %%
besta = 47.33220673 
bestb = 2.49423003

# %%
# here we have calculated the best possible A and b 
# Hence we will predict the power based on these values now, 
# formula is Power = A* Temp + b

# %%
train_boundry = int(df.shape[0] * 0.6)

findx = df.index.values[0]
mindx = df.index.values[train_boundry]

# %%
# Split the data
train = df.ix[findx:mindx, "power"]
test = df.ix[mindx:, "power"]

# %% [markdown]
# # !! Need to check the parameters

# %%
# Train the model
mod = sm.tsa.statespace.SARIMAX(train,
                                order=(0, 1, 1),
                                seasonal_order=(1, 1, 1, 1),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

# %% [markdown]
# # !! Reform the Predictions

# %%
pred = results.get_prediction(start=test.index[0], end=test.index[20], dynamic=False)
pred_ci = pred.conf_int()

# %%
pred_ci.head()
# Out:
#                      lower power  upper power
# 2016-07-06 13:42:00   559.306596  3641.952427
# 2016-07-06 13:44:00   -93.615860  2989.029840
# 2016-07-06 13:46:00   163.114564  3325.676996
# 2016-07-06 13:48:00    56.373995  3251.241630
# 2016-07-06 13:50:00    83.547852  3279.929284

# %%
pred

# %%
df_pred = pred_ci.mean(axis=1)

# %%
df_pred.head()
# Out:
# 2016-07-06 13:42:00    2100.629512
# 2016-07-06 13:44:00    1447.706990
# 2016-07-06 13:46:00    1744.395780
# 2016-07-06 13:48:00    1653.807813
# 2016-07-06 13:50:00    1681.738568
# Freq: 2T, dtype: float64

# %%
df_pred.plot()

# %%
# H and L for anomaly detection
alpha = 0.998

H = predicted.quantile(alpha)
L = predicted.quantile(1.0 - alpha)

# %%
print H, L

# %%
new_predicted = []
def anomalydetect(power_data, predicted, temp_data, A, b, H,L):

    k=0
    for i in range(len(new_predicted),len(power_data)):
        k=k+1
        actual_power = power_data[i]
        
        predicted_power = predicted[k]
        epsilon = (actual_power - predicted_power)/ predicted_power 
        new_p = 0
    
        # Positive Outlier
        if epsilon > H :
            new_p = A * temp_data[i] + b
            new_predicted.append(new_p)
        
        # Negative Outlier
        elif epsilon < L:
            new_p = A * temp_data[i] + b
            new_predicted.append(new_p)

# %%
anomalydetect(train,predicted,temp_data,besta,bestb,H,L)

# %%
new_predicted

# %%
plt.plot(new_predicted, color = "red")
#plt.plot(predicted, color= "green")
plt.plot(test)
plt.show()

# %% [markdown]
# # Unused Code

# %%
#simple 2 min resampling
#def returnsample(power):
#    returnempty = []
#    for i in range(0,round(power.shape[0]/120)-1):
#        empty = []
#        empty = power[i*120+1:i*120+120]
#        returnempty.append(np.average(empty))
#        
#    empty = power[120*(round(power.shape[0]/120)-1):]
#    returnempty.append(np.average(empty))
#    
#    return returnempty

# %%
#power_data = returnsample(power["Power"].values)
#temp_data = returnsample(temp["Temp"].values)

# %%
#power_data = np.array(power_data)
#power_data = power_data.astype(int)
#
#temp_data = np.array(temp_data)
#temp_data = temp_data.astype(int)

# %%
#print(len(power_data))
#len(temp_data)
